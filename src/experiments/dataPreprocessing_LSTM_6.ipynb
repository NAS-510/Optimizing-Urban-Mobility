# %%
# Import all necessary libraries.
import numpy as np
import pandas as pd
from sklearn  import preprocessing
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import seaborn as sns
sns.set_theme()

# %%
# Hyper parameters
########
num_of_feature = 8 # number of input features for LSTM and GRU network
past_observation = 24 # Number of past hours data used as input to the LSTM and GRU network
##########

######## Model Parameters # 
hidden_layers_unit = [128, 64, 32, 16]
return_sequence = [True, True, True, False]
batch_size = 64
num_of_epoch = 500

# %% [markdown]
# # Read dataset

# %%
# Import Dataset

traffic_data = pd.read_csv("/Users/nas/Documents/MRP/dataset/Metro_Interstate_Traffic_Volume.csv")
traffic_data = traffic_data.set_index(pd.DatetimeIndex(traffic_data['date_time'])).rename(columns={"date_time": "ds"})
traffic_data['ds'] = pd.to_datetime(traffic_data['ds'],infer_datetime_format=True)
# Out:
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_61922/1340887147.py:5: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   traffic_data['ds'] = pd.to_datetime(traffic_data['ds'],infer_datetime_format=True)

# %%
traffic_data
# Out:
#                     holiday    temp  rain_1h  snow_1h  clouds_all  \
# date_time
# 2012-10-02 09:00:00     NaN  288.28      0.0      0.0          40
# 2012-10-02 10:00:00     NaN  289.36      0.0      0.0          75
# 2012-10-02 11:00:00     NaN  289.58      0.0      0.0          90
# 2012-10-02 12:00:00     NaN  290.13      0.0      0.0          90
# 2012-10-02 13:00:00     NaN  291.14      0.0      0.0          75
# ...                     ...     ...      ...      ...         ...
# 2018-09-30 19:00:00     NaN  283.45      0.0      0.0          75
# 2018-09-30 20:00:00     NaN  282.76      0.0      0.0          90
# 2018-09-30 21:00:00     NaN  282.73      0.0      0.0          90
# 2018-09-30 22:00:00     NaN  282.09      0.0      0.0          90
# 2018-09-30 23:00:00     NaN  282.12      0.0      0.0          90
#
#                      weather_main     weather_description                  ds  \
# date_time
# 2012-10-02 09:00:00        Clouds        scattered clouds 2012-10-02 09:00:00
# 2012-10-02 10:00:00        Clouds           broken clouds 2012-10-02 10:00:00
# 2012-10-02 11:00:00        Clouds         overcast clouds 2012-10-02 11:00:00
# 2012-10-02 12:00:00        Clouds         overcast clouds 2012-10-02 12:00:00
# 2012-10-02 13:00:00        Clouds           broken clouds 2012-10-02 13:00:00
# ...                           ...                     ...                 ...
# 2018-09-30 19:00:00        Clouds           broken clouds 2018-09-30 19:00:00
# 2018-09-30 20:00:00        Clouds         overcast clouds 2018-09-30 20:00:00
# 2018-09-30 21:00:00  Thunderstorm  proximity thunderstorm 2018-09-30 21:00:00
# 2018-09-30 22:00:00        Clouds         overcast clouds 2018-09-30 22:00:00
# 2018-09-30 23:00:00        Clouds         overcast clouds 2018-09-30 23:00:00
#
#                      traffic_volume
# date_time
# 2012-10-02 09:00:00            5545
# 2012-10-02 10:00:00            4516
# 2012-10-02 11:00:00            4767
# 2012-10-02 12:00:00            5026
# 2012-10-02 13:00:00            4918
# ...                             ...
# 2018-09-30 19:00:00            3543
# 2018-09-30 20:00:00            2781
# 2018-09-30 21:00:00            2159
# 2018-09-30 22:00:00            1450
# 2018-09-30 23:00:00             954
#
# [48204 rows x 9 columns]

# %%
traffic_data = traffic_data.drop_duplicates()

# %%
# Checking for any missing or empty value
traffic_data.isna().sum()
# Out:
# holiday                48126
# temp                       0
# rain_1h                    0
# snow_1h                    0
# clouds_all                 0
# weather_main               0
# weather_description        0
# ds                         0
# traffic_volume             0
# dtype: int64

# %% [markdown]
# # convert categorical to nominal data

# %%
# Convert categorical value to numerical values. For holiday attribute, value will be within by 0 and 1. If it is holiday then 1 otherwise 0
label_encoder = preprocessing.LabelEncoder()
traffic_data['holiday'] = np.where(traffic_data.holiday=='None',0,1).astype('int64')
traffic_data['weather_main'] = label_encoder.fit_transform(traffic_data['weather_main'])
traffic_data['weather_description'] = label_encoder.fit_transform(traffic_data['weather_description'])
# Out:
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_61922/1522180088.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traffic_data['holiday'] = np.where(traffic_data.holiday=='None',0,1).astype('int64')
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_61922/1522180088.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traffic_data['weather_main'] = label_encoder.fit_transform(traffic_data['weather_main'])
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_61922/1522180088.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traffic_data['weather_description'] = label_encoder.fit_transform(traffic_data['weather_description'])

# %%
traffic_data.describe()
# Out:
#        holiday          temp       rain_1h       snow_1h    clouds_all  \
# count  48187.0  48187.000000  48187.000000  48187.000000  48187.000000
# mean       1.0    281.204995      0.334382      0.000222     49.365451
# min        1.0      0.000000      0.000000      0.000000      0.000000
# 25%        1.0    272.160000      0.000000      0.000000      1.000000
# 50%        1.0    282.450000      0.000000      0.000000     64.000000
# 75%        1.0    291.806000      0.000000      0.000000     90.000000
# max        1.0    310.070000   9831.300000      0.510000    100.000000
# std        0.0     13.338738     44.797033      0.008169     39.015213
#
#        weather_main  weather_description                             ds  \
# count  48187.000000         48187.000000                          48187
# mean       2.578642            16.540021  2016-01-05 06:49:48.133729024
# min        0.000000             0.000000            2012-10-02 09:00:00
# 25%        0.000000            10.000000            2014-02-06 07:30:00
# 50%        1.000000            17.000000            2016-06-10 21:00:00
# 75%        5.000000            27.000000            2017-08-11 05:30:00
# max       10.000000            37.000000            2018-09-30 23:00:00
# std        2.784148             8.969561                            NaN
#
#        traffic_volume
# count    48187.000000
# mean      3259.618134
# min          0.000000
# 25%       1192.500000
# 50%       3379.000000
# 75%       4933.000000
# max       7280.000000
# std       1986.954465

# %%
#traffic_data['temp'].plot()
traffic_data['rain_1h'].plot()
# Out:
# <Axes: xlabel='date_time'>

# %%
traffic_data['temp'].plot()
# Out:
# <Axes: xlabel='date_time'>

# %%
df1 = traffic_data['rain_1h']
df2 = traffic_data['temp']
#define number of rows and columns for subplots
nrow=1
ncol=2

# make a list of all dataframes 
df_list = [df1 ,df2]
df_title= ['rain_1h','temp']
fig, axes = plt.subplots(nrow, ncol, figsize=(10,5))
i = 0
for x in axes.flatten():
  df_list[i].plot(ax=x, color='mediumvioletred')
  x.set_title(df_title[i])
  i += 1
plt.savefig("/Users/nas/Documents/MRP/dataset/images/with_outlier.png", dpi=1200)

# %%
Q1 = traffic_data.quantile(0.25)
Q3 = traffic_data.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# holiday                               0.0
# temp                               19.646
# rain_1h                               0.0
# snow_1h                               0.0
# clouds_all                           89.0
# weather_main                          5.0
# weather_description                  17.0
# ds                     1281 days 22:00:00
# traffic_volume                     3740.5
# dtype: object

# %%
traffic_data=traffic_data[~((traffic_data['temp'] <(Q1['temp']-1.5*IQR['temp'])) | (traffic_data['temp'] >(Q1['temp']+1.5*IQR['temp'])))]
traffic_data=traffic_data[~((traffic_data['traffic_volume'] <(Q1['traffic_volume']-1.5*IQR['traffic_volume'])) | (traffic_data['traffic_volume'] >(Q1['traffic_volume']+1.5*IQR['traffic_volume'])))]

# %% [markdown]
# # Prepare training and testing data

# %%
# ploting traffic data to see to see any data imbalance
traffic_data['temp'].plot()
# Out:
# <Axes: xlabel='date_time'>

# %%
traffic_data['rain_1h'].plot()
# Out:
# <Axes: xlabel='date_time'>

# %%
df1 = traffic_data['rain_1h']
df2 = traffic_data['temp']
#define number of rows and columns for subplots
nrow=1
ncol=2

# make a list of all dataframes 
df_list = [df1 ,df2]
df_title= ['rain_1h','temp']
fig, axes = plt.subplots(nrow, ncol, figsize=(10,5))
i = 0
for x in axes.flatten():
  df_list[i].plot(ax=x, color='mediumvioletred')
  x.set_title(df_title[i])
  i += 1
plt.savefig("/Users/nas/Documents/MRP/dataset/images/without_outlier.png", dpi=1200)

# %%
traffic_data
# Out:
#                      holiday    temp  rain_1h  snow_1h  clouds_all  \
# date_time
# 2012-10-02 09:00:00        1  288.28      0.0      0.0          40
# 2012-10-02 10:00:00        1  289.36      0.0      0.0          75
# 2012-10-02 11:00:00        1  289.58      0.0      0.0          90
# 2012-10-02 12:00:00        1  290.13      0.0      0.0          90
# 2012-10-02 13:00:00        1  291.14      0.0      0.0          75
# ...                      ...     ...      ...      ...         ...
# 2018-09-30 19:00:00        1  283.45      0.0      0.0          75
# 2018-09-30 20:00:00        1  282.76      0.0      0.0          90
# 2018-09-30 21:00:00        1  282.73      0.0      0.0          90
# 2018-09-30 22:00:00        1  282.09      0.0      0.0          90
# 2018-09-30 23:00:00        1  282.12      0.0      0.0          90
#
#                      weather_main  weather_description                  ds  \
# date_time
# 2012-10-02 09:00:00             1                   24 2012-10-02 09:00:00
# 2012-10-02 10:00:00             1                    2 2012-10-02 10:00:00
# 2012-10-02 11:00:00             1                   19 2012-10-02 11:00:00
# 2012-10-02 12:00:00             1                   19 2012-10-02 12:00:00
# 2012-10-02 13:00:00             1                    2 2012-10-02 13:00:00
# ...                           ...                  ...                 ...
# 2018-09-30 19:00:00             1                    2 2018-09-30 19:00:00
# 2018-09-30 20:00:00             1                   19 2018-09-30 20:00:00
# 2018-09-30 21:00:00            10                   21 2018-09-30 21:00:00
# 2018-09-30 22:00:00             1                   19 2018-09-30 22:00:00
# 2018-09-30 23:00:00             1                   19 2018-09-30 23:00:00
#
#                      traffic_volume
# date_time
# 2012-10-02 09:00:00            5545
# 2012-10-02 10:00:00            4516
# 2012-10-02 11:00:00            4767
# 2012-10-02 12:00:00            5026
# 2012-10-02 13:00:00            4918
# ...                             ...
# 2018-09-30 19:00:00            3543
# 2018-09-30 20:00:00            2781
# 2018-09-30 21:00:00            2159
# 2018-09-30 22:00:00            1450
# 2018-09-30 23:00:00             954
#
# [47008 rows x 9 columns]

# %%
split_date = '2018-01-01'
train_data = traffic_data.loc[traffic_data.index <= split_date].copy()
test_data = traffic_data.loc[traffic_data.index > split_date].copy()

# %%
def plot_series(time, series, format='-', start=0, end=None):
    plt.plot(time[start:end], series[start:end],format)
    plt.xlabel('Time')
    plt.ylabel('Traffic Volume')
    plt.grid(True)

# %%
x_train = np.array(train_data['traffic_volume'])
x_valid = np.array(test_data['traffic_volume'])

time_train = np.array(train_data['ds'])
time_valid = np.array(test_data['ds'])

plt.figure(figsize=(20,6))
plot_series(time_train, x_train)

# %%
train_data_without_ds = train_data.drop(columns=['ds'])
train_data_without_ds
test_data_without_ds = test_data.drop(columns=['ds'])
test_data_without_ds
# Out:
#                      holiday    temp  rain_1h  snow_1h  clouds_all  \
# date_time
# 2018-01-01 01:00:00        1  249.08      0.0      0.0           1
# 2018-01-01 02:00:00        1  248.86      0.0      0.0           1
# 2018-01-01 03:00:00        1  248.72      0.0      0.0           1
# 2018-01-01 04:00:00        1  248.43      0.0      0.0           1
# 2018-01-01 05:00:00        1  248.07      0.0      0.0           1
# ...                      ...     ...      ...      ...         ...
# 2018-09-30 19:00:00        1  283.45      0.0      0.0          75
# 2018-09-30 20:00:00        1  282.76      0.0      0.0          90
# 2018-09-30 21:00:00        1  282.73      0.0      0.0          90
# 2018-09-30 22:00:00        1  282.09      0.0      0.0          90
# 2018-09-30 23:00:00        1  282.12      0.0      0.0          90
#
#                      weather_main  weather_description  traffic_volume
# date_time
# 2018-01-01 01:00:00             0                   27            1408
# 2018-01-01 02:00:00             0                   27             931
# 2018-01-01 03:00:00             0                   27             585
# 2018-01-01 04:00:00             0                   27             381
# 2018-01-01 05:00:00             0                   27             434
# ...                           ...                  ...             ...
# 2018-09-30 19:00:00             1                    2            3543
# 2018-09-30 20:00:00             1                   19            2781
# 2018-09-30 21:00:00            10                   21            2159
# 2018-09-30 22:00:00             1                   19            1450
# 2018-09-30 23:00:00             1                   19             954
#
# [7628 rows x 8 columns]

# %%
x_train = np.array(train_data['traffic_volume'])
x_valid = np.array(test_data['traffic_volume'])

time_train = np.array(train_data['ds'])
time_valid = np.array(test_data['ds'])

plt.figure(figsize=(10,4))
plot_series(time_valid, x_valid)

# %%
# Values of the attribute are in different scales. For example, holiday has maximum value 1 and traffic volume let say, 2000. Since these values are totally different range, it might be hurt model learning process. To overcome this issue, we need to do data normalization or standarization.
sc = MinMaxScaler()
sc_test = MinMaxScaler()
training_data_set = sc.fit_transform(train_data_without_ds)
training_data_frame = pd.DataFrame(training_data_set)
test_data_set = sc_test.fit_transform(test_data_without_ds)
test_data_frame = pd.DataFrame(test_data_set)

# %%
# Make data for the LSTM model. I used past t-hours of data to predict the next 'n' hours data. Here window_size means window size data will be used for predicting next 'n' hours data

def df_to_x_y(data, window_size=5):
    X = []
    y = []
    for i in range(len(data)-window_size):
        row = [r for r in data[i:i+window_size]]
        X.append(row)
        label = data[i+window_size][num_of_feature-1]
        y.append(label)
    return np.array(X), np.array(y)

X, y = df_to_x_y(training_data_set,past_observation)
X.shape, y.shape
# Out:
# ((39356, 24, 8), (39356,))

# %%
# X test y Test
X_test, y_test = df_to_x_y(test_data_set, past_observation)
X_test.shape, y_test.shape
# Out:
# ((7604, 24, 8), (7604,))

# %%
# split data into train test and validation datase
from cgi import test


train_length = int(len(X)*0.9) # 80% trainging
validation_length = int(len(X)*.10) # 10% testing and rest for validation
print(train_length, validation_length, (train_length+validation_length))
X_train, y_train = X[:train_length],y[:train_length]
X_val, y_val = X[train_length:], y[train_length:]
# Out:
# 35420 3935 39355

# %%
(X_train.shape, y_train.shape), (X_val.shape, y_val.shape)
# Out:
# (((35420, 24, 8), (35420,)), ((3936, 24, 8), (3936,)))

# %%
# Define the LSTM_Model
LSTM_Model = Sequential()
# Add layers to the LSTM_Model

# Compile the LSTM_Model
LSTM_Model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanAbsolutePercentageError()])

# %%
GRU_Model = Sequential()
# Add layers to the GRU_Model

GRU_Model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanAbsolutePercentageError()])

# %%
LSTM_CheckPoint = ModelCheckpoint('/Users/nas/Documents/MRP/Traffic-Volume-Prediction-LSTM-GRU-main/model/model_lstm_6.keras', save_best_only=True)
GRU_CheckPoint = ModelCheckpoint('/Users/nas/Documents/MRP/Traffic-Volume-Prediction-LSTM-GRU-main/model/model_gru_6.keras', save_best_only=True)
earlyStop =  tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=10, mode='min')

# %%
LSTM_Model.add(LSTM(units=hidden_layers_unit[0], return_sequences=return_sequence[0], input_shape=(past_observation, num_of_feature)))
LSTM_Model.add(Dropout(0.2))

for i in range(1, len(hidden_layers_unit)):
    LSTM_Model.add(LSTM(units=hidden_layers_unit[i], return_sequences=return_sequence[i]))
    LSTM_Model.add(Dropout(0.2))

LSTM_Model.add(Dense(units=1))
# Out:
# /Users/nas/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
GRU_Model.add(GRU(units=hidden_layers_unit[0], return_sequences=return_sequence[0], input_shape=(past_observation, num_of_feature)))
GRU_Model.add(Dropout(0.2))

for i in range(1, len(hidden_layers_unit)):
    GRU_Model.add(GRU(units=hidden_layers_unit[i], return_sequences=return_sequence[i]))
    GRU_Model.add(Dropout(0.2))

GRU_Model.add(Dense(units=1))

# %%
LSTM_Model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanAbsolutePercentageError()], run_eagerly=True)
GRU_Model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanAbsolutePercentageError()], run_eagerly=True)
ax[1].legend(['Training Loss', 'Validation Loss'], loc='upper right')
plt.savefig("/Users/nas/Documents/MRP/dataset/images/training_loss.png", dpi=1200)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 3
#       1 LSTM_Model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanAbsolutePercentageError()], run_eagerly=True)
#       2 GRU_Model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanAbsolutePercentageError()], run_eagerly=True)
# ----> 3 ax[1].legend(['Training Loss', 'Validation Loss'], loc='upper right')
#       4 plt.savefig("/Users/nas/Documents/MRP/dataset/images/training_loss.png", dpi=1200)
#       5 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'legend'

# %%
# summarize history for loss
LSTM_history = LSTM_Model.fit(X_train, y_train, epochs=num_of_epoch, batch_size=batch_size, validation_data=(X_val, y_val), callbacks=[LSTM_CheckPoint, earlyStop], verbose=1)
fig, ax = plt.subplots(2,2, figsize=(16,8))
ax[0][0].plot(LSTM_history.history['mean_absolute_error'], color='red')
ax[0][0].plot(LSTM_history.history['val_mean_absolute_error'], color='crimson')
ax[0][0].set_title('Mean Absolute Error (LSTM)')
ax[0][0].set_ylabel('Error')
ax[0][0].set_xlabel('Epoch')
ax[0][0].legend(['Training Error', 'Validation Error'], loc='upper right')

ax[0][1].plot(LSTM_history.history['mean_absolute_percentage_error'], color='red')
ax[0][1].plot(LSTM_history.history['val_mean_absolute_percentage_error'], color='crimson')
ax[0][1].set_title('Mean Absolute Percentatge Error (LSTM)')
ax[0][1].set_ylabel('Error')
ax[0][1].set_xlabel('Epoch')
ax[0][1].legend(['Training Error', 'Validation Error'], loc='upper right')


ax[1][0].plot(GRU_history.history['mean_absolute_error'], color='orangered')
ax[1][0].plot(GRU_history.history['val_mean_absolute_error'], color='firebrick')
ax[1][0].set_title('Mean Absolute Error (GRU)')
ax[1][0].set_ylabel('Loss')
ax[1][0].set_xlabel('Epoch')
ax[1][0].legend(['Training Loss', 'Validation Loss'], loc='upper right')

ax[1][1].plot(GRU_history.history['mean_absolute_percentage_error'], color='orangered')
ax[1][1].plot(GRU_history.history['val_mean_absolute_percentage_error'], color='firebrick')
ax[1][1].set_title('Mean Absolute Percentatge Error (GRU)')
ax[1][1].set_ylabel('Error')
ax[1][1].set_xlabel('Epoch')
ax[1][1].legend(['Training Error', 'Validation Error'], loc='upper right')
fig.tight_layout()
plt.savefig("/Users/nas/Documents/MRP/dataset/images/mean_absolute_error_loss.png", dpi=1200)
plt.show()
# Out:
# Epoch 1/500
#  87/554 ━━━━━━━━━━━━━━━━━━━━ 1:08 147ms/step - loss: 0.1585 - mean_absolute_error: 0.3291 - mean_absolute_percentage_error: 207.9470
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 2
#       1 # summarize history for loss
# ----> 2 LSTM_history = LSTM_Model.fit(X_train, y_train, epochs=num_of_epoch, batch_size=batch_size, validation_data=(X_val, y_val), callbacks=[LSTM_CheckPoint, earlyStop], verbose=1)
#       3 fig, ax = plt.subplots(2,2, figsize=(16,8))
#       4 ax[0][0].plot(LSTM_history.history['mean_absolute_error'], color='red')
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py:117, in TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator(iterator)
#     115 """Runs a single training step given a Dataset iterator."""
#     116 data = next(iterator)
# --> 117 outputs = self.distribute_strategy.run(
#     118     one_step_on_data, args=(data,)
#     119 )
#     120 outputs = reduce_per_replica(
#     121     outputs,
#     122     self.distribute_strategy,
#     123     reduction="auto",
#     124 )
#     125 return outputs
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:1673, in StrategyBase.run(***failed resolving arguments***)
#    1668 with self.scope():
#    1669   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1670   # applied when the caller is also in Eager mode.
#    1671   fn = autograph.tf_convert(
#    1672       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1673   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:3263, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    3261   kwargs = {}
#    3262 with self._container_strategy().scope():
# -> 3263   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:4061, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    4059 def _call_for_each_replica(self, fn, args, kwargs):
#    4060   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4061     return fn(*args, **kwargs)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py:104, in TensorFlowTrainer.make_train_function.<locals>.one_step_on_data(data)
#     101 @tf.autograph.experimental.do_not_convert
#     102 def one_step_on_data(data):
#     103     """Runs a single training step on a batch of data."""
# --> 104     return self.train_step(data)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py:51, in TensorFlowTrainer.train_step(self, data)
#      49 with tf.GradientTape() as tape:
#      50     if self._call_has_training_arg:
# ---> 51         y_pred = self(x, training=True)
#      52     else:
#      53         y_pred = self(x)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/layers/layer.py:846, in Layer.__call__(self, *args, **kwargs)
#     844         outputs = super().__call__(*args, **kwargs)
#     845 else:
# --> 846     outputs = super().__call__(*args, **kwargs)
#     847 # Change the layout for the layer output if needed.
#     848 # This is useful for relayout intermediate tensor in the model
#     849 # to achieve the optimal performance.
#     850 distribution = distribution_lib.distribution()
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/ops/operation.py:48, in Operation.__call__(self, *args, **kwargs)
#      43             call_fn = self.call
#      44     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      45         call_fn,
#      46         object_name=(f"{self.__class__.__name__}.call()"),
#      47     )
# ---> 48     return call_fn(*args, **kwargs)
#      50 # Plain flow.
#      51 if any_symbolic_tensors(args, kwargs):
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/models/sequential.py:209, in Sequential.call(self, inputs, training, mask)
#     207 def call(self, inputs, training=None, mask=None):
#     208     if self._functional:
# --> 209         return self._functional.call(inputs, training=training, mask=mask)
#     211     # Fallback: Just apply the layer sequence.
#     212     # This typically happens if `inputs` is a nested struct.
#     213     for layer in self.layers:
#     214         # During each iteration, `inputs` are the inputs to `layer`, and
#     215         # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     216         # end of each iteration `inputs` is set to `outputs` to prepare for
#     217         # the next layer.
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/models/functional.py:202, in Functional.call(self, inputs, training, mask)
#     200         if mask is not None:
#     201             x._keras_mask = mask
# --> 202 outputs = self._run_through_graph(
#     203     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     204 )
#     205 return unpack_singleton(outputs)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/ops/function.py:155, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     153     outputs = call_fn(op, *args, **kwargs)
#     154 else:
# --> 155     outputs = op(*args, **kwargs)
#     157 # Update tensor_dict.
#     158 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/models/functional.py:592, in operation_fn.<locals>.call(*args, **kwargs)
#     586 if (
#     587     hasattr(operation, "_call_has_training_arg")
#     588     and operation._call_has_training_arg
#     589     and training is not None
#     590 ):
#     591     kwargs["training"] = training
# --> 592 return operation(*args, **kwargs)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/layers/layer.py:846, in Layer.__call__(self, *args, **kwargs)
#     844         outputs = super().__call__(*args, **kwargs)
#     845 else:
# --> 846     outputs = super().__call__(*args, **kwargs)
#     847 # Change the layout for the layer output if needed.
#     848 # This is useful for relayout intermediate tensor in the model
#     849 # to achieve the optimal performance.
#     850 distribution = distribution_lib.distribution()
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/ops/operation.py:48, in Operation.__call__(self, *args, **kwargs)
#      43             call_fn = self.call
#      44     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      45         call_fn,
#      46         object_name=(f"{self.__class__.__name__}.call()"),
#      47     )
# ---> 48     return call_fn(*args, **kwargs)
#      50 # Plain flow.
#      51 if any_symbolic_tensors(args, kwargs):
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/layers/rnn/lstm.py:560, in LSTM.call(self, sequences, initial_state, mask, training)
#     559 def call(self, sequences, initial_state=None, mask=None, training=False):
# --> 560     return super().call(
#     561         sequences, mask=mask, training=training, initial_state=initial_state
#     562     )
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:406, in RNN.call(self, sequences, initial_state, mask, training)
#     400 # Prepopulate the dropout state so that the inner_loop is stateless
#     401 # this is particularly important for JAX backend.
#     402 self._maybe_config_dropout_masks(
#     403     self.cell, sequences[:, 0, :], initial_state
#     404 )
# --> 406 last_output, outputs, states = self.inner_loop(
#     407     sequences=sequences,
#     408     initial_state=initial_state,
#     409     mask=mask,
#     410     training=training,
#     411 )
#     412 last_output = ops.cast(last_output, self.compute_dtype)
#     413 outputs = ops.cast(outputs, self.compute_dtype)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/layers/rnn/lstm.py:555, in LSTM.inner_loop(self, sequences, initial_state, mask, training)
#     548 if self.use_cudnn is True:
#     549     raise ValueError(
#     550         "use_cudnn=True was specified, "
#     551         "but cuDNN is not supported for this layer configuration "
#     552         "with this backend. Pass use_cudnn='auto' to fallback "
#     553         "to a non-cuDNN implementation."
#     554     )
# --> 555 return super().inner_loop(
#     556     sequences, initial_state, mask=mask, training=training
#     557 )
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:346, in RNN.inner_loop(self, sequences, initial_state, mask, training)
#     343 if not tree.is_nested(initial_state):
#     344     initial_state = [initial_state]
# --> 346 return backend.rnn(
#     347     step,
#     348     sequences,
#     349     initial_state,
#     350     go_backwards=self.go_backwards,
#     351     mask=mask,
#     352     unroll=self.unroll,
#     353     input_length=sequences.shape[1],
#     354     zero_output_for_mask=self.zero_output_for_mask,
#     355     return_all_outputs=self.return_sequences,
#     356 )
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/rnn.py:428, in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask, return_all_outputs)
#     423         new_states = tree.pack_sequence_as(
#     424             initial_states, flat_new_state
#     425         )
#     426         return (time + 1, output_ta_t) + tuple(new_states)
# --> 428     final_outputs = tf.while_loop(
#     429         body=_step,
#     430         loop_vars=(time, output_ta) + states,
#     431         **while_loop_kwargs,
#     432     )
#     433     new_states = final_outputs[2:]
#     435 output_ta = final_outputs[1]
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:660, in deprecated_arg_values.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     652           _PRINTED_WARNING[(func, arg_name)] = True
#     653         _log_deprecation(
#     654             'From %s: calling %s (from %s) with %s=%s is deprecated and '
#     655             'will be removed %s.\nInstructions for updating:\n%s',
#    (...)
#     658             'in a future version' if date is None else
#     659             ('after %s' % date), instructions)
# --> 660 return func(*args, **kwargs)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/ops/while_loop.py:241, in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#      35 @tf_export("while_loop", v1=[])
#      36 @deprecation.deprecated_arg_values(
#      37     None,
#    (...)
#      52                   maximum_iterations=None,
#      53                   name=None):
#      54   """Repeat `body` while the condition `cond` is true.
#      55
#      56   Note: This op is automatically used in a `tf.function` to convert Python for-
#    (...)
#     239
#     240   """
# --> 241   return while_loop(
#     242       cond=cond,
#     243       body=body,
#     244       loop_vars=loop_vars,
#     245       shape_invariants=shape_invariants,
#     246       parallel_iterations=parallel_iterations,
#     247       back_prop=back_prop,
#     248       swap_memory=swap_memory,
#     249       name=name,
#     250       maximum_iterations=maximum_iterations,
#     251       return_same_structure=True)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/ops/while_loop.py:488, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#     485 loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#     486                                         list(loop_vars))
#     487 while cond(*loop_vars):
# --> 488   loop_vars = body(*loop_vars)
#     489   if try_to_pack and not isinstance(loop_vars, (list, tuple)):
#     490     packed = True
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/ops/while_loop.py:479, in while_loop.<locals>.<lambda>(i, lv)
#     476     loop_vars = (counter, loop_vars)
#     477     cond = lambda i, lv: (  # pylint: disable=g-long-lambda
#     478         math_ops.logical_and(i < maximum_iterations, orig_cond(*lv)))
# --> 479     body = lambda i, lv: (i + 1, orig_body(*lv))
#     480   try_to_pack = False
#     482 if executing_eagerly:
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/rnn.py:411, in rnn.<locals>._step(time, output_ta_t, *states)
#     409 current_input = tuple(ta.read(time) for ta in input_ta)
#     410 current_input = tree.pack_sequence_as(inputs, current_input)
# --> 411 output, new_states = step_function(
#     412     current_input, tuple(states) + tuple(constants)
#     413 )
#     414 flat_new_state = tree.flatten(new_states)
#     416 flat_output = tree.flatten(output)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:338, in RNN.inner_loop.<locals>.step(inputs, states)
#     337 def step(inputs, states):
# --> 338     output, new_states = self.cell(inputs, states, **cell_kwargs)
#     339     if not tree.is_nested(new_states):
#     340         new_states = [new_states]
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/layers/layer.py:846, in Layer.__call__(self, *args, **kwargs)
#     844         outputs = super().__call__(*args, **kwargs)
#     845 else:
# --> 846     outputs = super().__call__(*args, **kwargs)
#     847 # Change the layout for the layer output if needed.
#     848 # This is useful for relayout intermediate tensor in the model
#     849 # to achieve the optimal performance.
#     850 distribution = distribution_lib.distribution()
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/ops/operation.py:48, in Operation.__call__(self, *args, **kwargs)
#      43             call_fn = self.call
#      44     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      45         call_fn,
#      46         object_name=(f"{self.__class__.__name__}.call()"),
#      47     )
# ---> 48     return call_fn(*args, **kwargs)
#      50 # Plain flow.
#      51 if any_symbolic_tensors(args, kwargs):
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/layers/rnn/lstm.py:264, in LSTMCell.call(self, inputs, states, training)
#     262     c, o = self._compute_carry_and_output(x, h_tm1, c_tm1)
#     263 else:
# --> 264     z = ops.matmul(inputs, self.kernel)
#     266     z += ops.matmul(h_tm1, self.recurrent_kernel)
#     267     if self.use_bias:
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/ops/numpy.py:3440, in matmul(x1, x2)
#    3438 if any_symbolic_tensors((x1, x2)):
#    3439     return Matmul().symbolic_call(x1, x2)
# -> 3440 return backend.numpy.matmul(x1, x2)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/numpy.py:375, in matmul(x1, x2)
#     373     output_type = None
#     374 x1 = tf.cast(x1, compute_dtype)
# --> 375 x2 = tf.cast(x2, compute_dtype)
#     377 def with_combined_batch_dimensions(a, b, output_shape, fn_3d):
#     378     a_sparse = isinstance(a, tf.SparseTensor)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:1010, in cast(x, dtype, name)
#    1004   x = indexed_slices.IndexedSlices(values_cast, x.indices, x.dense_shape)
#    1005 else:
#    1006   # TODO(josh11b): If x is not already a Tensor, we could return
#    1007   # ops.convert_to_tensor(x, dtype=dtype, ...)  here, but that
#    1008   # allows some conversions that cast() can't do, e.g. casting numbers to
#    1009   # strings.
# -> 1010   x = ops.convert_to_tensor(x, name="x")
#    1011   if x.dtype.is_complex and base_type.is_floating:
#    1012     logging.warn(
#    1013         f"You are casting an input of type {x.dtype.name} to an "
#    1014         f"incompatible dtype {base_type.name}.  This will "
#    1015         "discard the imaginary part and may not be what you "
#    1016         "intended."
#    1017     )
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:713, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     711 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     712 preferred_dtype = preferred_dtype or dtype_hint
# --> 713 return tensor_conversion_registry.convert(
#     714     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     715 )
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:209, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207 overload = getattr(value, "__tf_tensor__", None)
#     208 if overload is not None:
# --> 209   return overload(dtype, name)  #  pylint: disable=not-callable
#     211 for base_type, conversion_func in get(type(value)):
#     212   # If dtype is None but preferred_dtype is not None, we try to
#     213   # cast to preferred_dtype first.
#     214   ret = None
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/core.py:65, in Variable.__tf_tensor__(self, dtype, name)
#      64 def __tf_tensor__(self, dtype=None, name=None):
# ---> 65     return tf.convert_to_tensor(self.value, dtype=dtype, name=name)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/framework/tensor_conversion.py:161, in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#      96 @tf_export.tf_export("convert_to_tensor", v1=[])
#      97 @dispatch.add_dispatch_support
#      98 def convert_to_tensor_v2_with_dispatch(
#      99     value, dtype=None, dtype_hint=None, name=None
#     100 ) -> tensor_lib.Tensor:
#     101   """Converts the given `value` to a `Tensor`.
#     102
#     103   This function converts Python objects of various types to `Tensor`
#    (...)
#     159     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#     160   """
# --> 161   return convert_to_tensor_v2(
#     162       value, dtype=dtype, dtype_hint=dtype_hint, name=name
#     163   )
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/framework/tensor_conversion.py:171, in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#     169 """Converts the given `value` to a `Tensor`."""
#     170 # preferred_dtype = preferred_dtype or dtype_hint
# --> 171 return tensor_conversion_registry.convert(
#     172     value, dtype, name, preferred_dtype=dtype_hint
#     173 )
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:2331, in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2330 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2331   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:1577, in BaseResourceVariable._dense_var_to_tensor(***failed resolving arguments***)
#    1575   return self.read_value().op.inputs[0]
#    1576 else:
# -> 1577   return self.value()
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:629, in BaseResourceVariable.value(self)
#     627   return self._cached_value
#     628 with ops.colocate_with(None, ignore_existing=True):
# --> 629   return self._read_variable_op()
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:813, in BaseResourceVariable._read_variable_op(self, no_copy)
#     811       result = read_and_set_handle(no_copy)
#     812 else:
# --> 813   result = read_and_set_handle(no_copy)
#     815 if not context.executing_eagerly():
#     816   # Note that if a control flow context is active the input of the read op
#     817   # might not actually be the handle. This line bypasses it.
#     818   record.record_operation(
#     819       "ReadVariableOp", [result], [self.handle],
#     820       backward_function=lambda x: [x],
#     821       forward_function=lambda x: [x])
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:803, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     801 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     802   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 803 result = gen_resource_variable_ops.read_variable_op(
#     804     self.handle, self._dtype)
#     805 _maybe_set_handle_data(self._dtype, self.handle, result)
#     806 return result
#
# File ~/Documents/MRP/venv/lib/python3.9/site-packages/tensorflow/python/ops/gen_resource_variable_ops.py:534, in read_variable_op(resource, dtype, name)
#     532 if tld.is_eager:
#     533   try:
# --> 534     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     535       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     536     return _result
#     537   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
from tensorflow.keras.models import load_model
lstm_model = load_model('model/model_lstm_6.keras')
gru_model = load_model('model/model_gru.keras')

# %%
lstm_prediction = lstm_model.predict(X_test)
gru_prediction = gru_model.predict(X_test)
# Out:
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 14s 60ms/step
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step

# %%
from tabnanny import verbose


lstm_evaluation = lstm_model.evaluate(X_test, y_test, verbose=0)
gru_evaluation = gru_model.evaluate(X_test, y_test, verbose=0)

# %%
(lstm_evaluation, gru_evaluation)
# Out:
# ([0.004336453974246979, 0.04519724100828171, 24070.583984375],
#  0.004293637350201607)

# %%
print(f'LSTM: Loss: {np.round(lstm_evaluation[0],4)}, Mean Absolute Error: {np.round(lstm_evaluation[1],4)}, MAPE: {np.round(lstm_evaluation[2],4)}')
# Out:
# LSTM: Loss: 0.0043, Mean Absolute Error: 0.0452, MAPE: 24070.584

# %%
lstm_Y = np.repeat(lstm_prediction, num_of_feature, axis=1)
lstm_y_inverse = sc_test.inverse_transform(lstm_Y)
gru_Y = np.repeat(gru_prediction, num_of_feature, axis=1)
gru_y_inverse = sc_test.inverse_transform(gru_Y)

# %%
Y_test = np.repeat(y_test, num_of_feature)
Y_test = Y_test.reshape(-1,num_of_feature)
Y_Test_transfer = sc_test.inverse_transform(Y_test)

# %%
lstm_Y_pred = lstm_y_inverse[:, 7]
gru_Y_pred = gru_y_inverse[:,7]
actual_Y_test = Y_Test_transfer[:, 7]

# %%
def plot_series(time, series_true, series_pred, format='-', start=0, end=None):
    plt.plot(time[start:end], series_true[start:end],format)
    plt.plot(time[start:end], series_pred[start:end],format)
    plt.xlabel('Time')
    plt.ylabel('Traffic Volume')
    plt.grid(True)
    plt.show()

# %%
lstm_y_pred = np.array(lstm_Y_pred)
gru_y_pred = np.array(gru_Y_pred)
y_true = np.array(actual_Y_test)

time_test = np.array(test_data['ds'])

plt.figure(figsize=(10,6))
plot_series(time_test[:50], y_true[:50],lstm_y_pred[:50])
plt.figure(figsize=(10,6))
plot_series(time_test[:50], y_true[:50],gru_y_pred[:50])

# %%
def plot_series_subplot(time, series_true, series_pred, ax,title="",format='-', start=0, end=None):
    xlabels = [str(time[i])[0:13] for i in range(len(time))]
    ax.plot(time[start:end], series_true[start:end],format)
    ax.plot(time[start:end], series_pred[start:end],format)
    ax.set_xlabel('Time')
    ax.set_title(title)
    #ax.set_xticks(time[start:end])
    ax.set_xticklabels(xlabels, rotation=50)
    ax.legend(['Actual','Predicted'], loc='best')
    ax.set_ylabel('Traffic Volume')
    ax.grid(True)

# %%
fig, ax = plt.subplots(2,2, figsize=(20,6))
plot_series_subplot(time_test[:50], y_true[:50],lstm_y_pred[:50],ax[0][0], "LSTM Prediction")
#plt.figure(figsize=(10,6))
plot_series_subplot(time_test[:50], y_true[:50],gru_y_pred[:50], ax[0][1],"GRU Prediction")
plot_series_subplot(time_test[200:300], y_true[200:300],lstm_y_pred[200:300],ax[1][0], "LSTM Prediction")
plot_series_subplot(time_test[200:300], y_true[200:300],gru_y_pred[200:300], ax[1][1],"GRU Prediction")
fig.tight_layout()
plt.savefig("/Users/nas/Documents/MRP/dataset/images/prediction_1.png", dpi=1200)
# Out:
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_3228/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_3228/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_3228/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_3228/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)

# %%
fig, ax = plt.subplots(2,2, figsize=(20,6))
plot_series_subplot(time_test[1000:1200], y_true[1000:1200],lstm_y_pred[1000:1200],ax[0][0], "LSTM Prediction")
plot_series_subplot(time_test[1000:1200], y_true[1000:1200],gru_y_pred[1000:1200], ax[0][1],"GRU Prediction")

plot_series_subplot(time_test[0:500], y_true[0:500],lstm_y_pred[0:500],ax[1][0], "LSTM Prediction")
plot_series_subplot(time_test[0:500], y_true[0:500],gru_y_pred[0:500], ax[1][1],"GRU Prediction")
fig.tight_layout()
plt.savefig("/Users/nas/Documents/MRP/dataset/images/prediction_1.png", dpi=1200)
# Out:
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_3228/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_3228/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_3228/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_3228/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)

# %%
fig, ax = plt.subplots(2,2, figsize=(20,6))
plot_series_subplot(time_test[50:80], y_true[50:80],lstm_y_pred[50:80],ax[0][0], "LSTM Prediction")
plot_series_subplot(time_test[50:80], y_true[50:80],gru_y_pred[50:80], ax[0][1],"GRU Prediction")

plot_series_subplot(time_test[100:120], y_true[100:120],lstm_y_pred[100:120],ax[1][0], "LSTM Prediction")
plot_series_subplot(time_test[100:120], y_true[100:120],gru_y_pred[100:120], ax[1][1],"GRU Prediction")
fig.tight_layout()
plt.savefig("/Users/nas/Documents/MRP/dataset/images/prediction_2.png", dpi=1200)
# Out:
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_3228/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_3228/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_3228/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_3228/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)

# %%
fig, ax = plt.subplots(2,2, figsize=(20,6))
plot_series_subplot(time_test[50:80], y_true[50:80],lstm_y_pred[50:80],ax[0][0], "LSTM Prediction")
plot_series_subplot(time_test[50:80], y_true[50:80],gru_y_pred[50:80], ax[0][1],"GRU Prediction")

plot_series_subplot(time_test[300:400], y_true[300:400],lstm_y_pred[300:400],ax[1][0], "LSTM Prediction")
plot_series_subplot(time_test[300:400], y_true[300:400],gru_y_pred[300:400], ax[1][1],"GRU Prediction")
fig.tight_layout()
plt.savefig("/Users/nas/Documents/MRP/dataset/images/prediction_2.png", dpi=1200)
# Out:
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_3228/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_3228/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_3228/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_3228/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)

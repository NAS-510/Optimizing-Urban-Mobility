# %%
# Import all necessary libraries.
import numpy as np
import pandas as pd
from sklearn  import preprocessing
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import seaborn as sns
sns.set_theme()
# Out:
# /Users/nas/Documents/MRP/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Hyper parameters
########
num_of_feature = 8 # number of input features for LSTM and GRU network
past_observation = 24 # Number of past hours data used as input to the LSTM and GRU network
##########

######## Model Parameters # 
hidden_layers_unit = [128, 64, 32, 16]
return_sequence = [True, True, True, False]
batch_size = 256
num_of_epoch = 500

# %% [markdown]
# # Read dataset

# %%
# Import Dataset

traffic_data = pd.read_csv("/Users/nas/Documents/MRP/dataset/Metro_Interstate_Traffic_Volume.csv")
traffic_data = traffic_data.set_index(pd.DatetimeIndex(traffic_data['date_time'])).rename(columns={"date_time": "ds"})
traffic_data['ds'] = pd.to_datetime(traffic_data['ds'],infer_datetime_format=True)
# Out:
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/1340887147.py:5: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   traffic_data['ds'] = pd.to_datetime(traffic_data['ds'],infer_datetime_format=True)

# %%
traffic_data
# Out:
#                     holiday    temp  rain_1h  snow_1h  clouds_all  \
# date_time
# 2012-10-02 09:00:00     NaN  288.28      0.0      0.0          40
# 2012-10-02 10:00:00     NaN  289.36      0.0      0.0          75
# 2012-10-02 11:00:00     NaN  289.58      0.0      0.0          90
# 2012-10-02 12:00:00     NaN  290.13      0.0      0.0          90
# 2012-10-02 13:00:00     NaN  291.14      0.0      0.0          75
# ...                     ...     ...      ...      ...         ...
# 2018-09-30 19:00:00     NaN  283.45      0.0      0.0          75
# 2018-09-30 20:00:00     NaN  282.76      0.0      0.0          90
# 2018-09-30 21:00:00     NaN  282.73      0.0      0.0          90
# 2018-09-30 22:00:00     NaN  282.09      0.0      0.0          90
# 2018-09-30 23:00:00     NaN  282.12      0.0      0.0          90
#
#                      weather_main     weather_description                  ds  \
# date_time
# 2012-10-02 09:00:00        Clouds        scattered clouds 2012-10-02 09:00:00
# 2012-10-02 10:00:00        Clouds           broken clouds 2012-10-02 10:00:00
# 2012-10-02 11:00:00        Clouds         overcast clouds 2012-10-02 11:00:00
# 2012-10-02 12:00:00        Clouds         overcast clouds 2012-10-02 12:00:00
# 2012-10-02 13:00:00        Clouds           broken clouds 2012-10-02 13:00:00
# ...                           ...                     ...                 ...
# 2018-09-30 19:00:00        Clouds           broken clouds 2018-09-30 19:00:00
# 2018-09-30 20:00:00        Clouds         overcast clouds 2018-09-30 20:00:00
# 2018-09-30 21:00:00  Thunderstorm  proximity thunderstorm 2018-09-30 21:00:00
# 2018-09-30 22:00:00        Clouds         overcast clouds 2018-09-30 22:00:00
# 2018-09-30 23:00:00        Clouds         overcast clouds 2018-09-30 23:00:00
#
#                      traffic_volume
# date_time
# 2012-10-02 09:00:00            5545
# 2012-10-02 10:00:00            4516
# 2012-10-02 11:00:00            4767
# 2012-10-02 12:00:00            5026
# 2012-10-02 13:00:00            4918
# ...                             ...
# 2018-09-30 19:00:00            3543
# 2018-09-30 20:00:00            2781
# 2018-09-30 21:00:00            2159
# 2018-09-30 22:00:00            1450
# 2018-09-30 23:00:00             954
#
# [48204 rows x 9 columns]

# %%
traffic_data = traffic_data.drop_duplicates()

# %%
# Checking for any missing or empty value
traffic_data.isna().sum()
# Out:
# holiday                48126
# temp                       0
# rain_1h                    0
# snow_1h                    0
# clouds_all                 0
# weather_main               0
# weather_description        0
# ds                         0
# traffic_volume             0
# dtype: int64

# %% [markdown]
# # convert categorical to nominal data

# %%
# Convert categorical value to numerical values. For holiday attribute, value will be within by 0 and 1. If it is holiday then 1 otherwise 0
label_encoder = preprocessing.LabelEncoder()
traffic_data['holiday'] = np.where(traffic_data.holiday=='None',0,1).astype('int64')
traffic_data['weather_main'] = label_encoder.fit_transform(traffic_data['weather_main'])
traffic_data['weather_description'] = label_encoder.fit_transform(traffic_data['weather_description'])
# Out:
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/1522180088.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traffic_data['holiday'] = np.where(traffic_data.holiday=='None',0,1).astype('int64')
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/1522180088.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traffic_data['weather_main'] = label_encoder.fit_transform(traffic_data['weather_main'])
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/1522180088.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traffic_data['weather_description'] = label_encoder.fit_transform(traffic_data['weather_description'])

# %%
traffic_data.describe()
# Out:
#        holiday          temp       rain_1h       snow_1h    clouds_all  \
# count  48187.0  48187.000000  48187.000000  48187.000000  48187.000000
# mean       1.0    281.204995      0.334382      0.000222     49.365451
# min        1.0      0.000000      0.000000      0.000000      0.000000
# 25%        1.0    272.160000      0.000000      0.000000      1.000000
# 50%        1.0    282.450000      0.000000      0.000000     64.000000
# 75%        1.0    291.806000      0.000000      0.000000     90.000000
# max        1.0    310.070000   9831.300000      0.510000    100.000000
# std        0.0     13.338738     44.797033      0.008169     39.015213
#
#        weather_main  weather_description                             ds  \
# count  48187.000000         48187.000000                          48187
# mean       2.578642            16.540021  2016-01-05 06:49:48.133729024
# min        0.000000             0.000000            2012-10-02 09:00:00
# 25%        0.000000            10.000000            2014-02-06 07:30:00
# 50%        1.000000            17.000000            2016-06-10 21:00:00
# 75%        5.000000            27.000000            2017-08-11 05:30:00
# max       10.000000            37.000000            2018-09-30 23:00:00
# std        2.784148             8.969561                            NaN
#
#        traffic_volume
# count    48187.000000
# mean      3259.618134
# min          0.000000
# 25%       1192.500000
# 50%       3379.000000
# 75%       4933.000000
# max       7280.000000
# std       1986.954465

# %%
#traffic_data['temp'].plot()
traffic_data['rain_1h'].plot()
# Out:
# <Axes: xlabel='date_time'>

# %%
traffic_data['temp'].plot()
# Out:
# <Axes: xlabel='date_time'>

# %%
df1 = traffic_data['rain_1h']
df2 = traffic_data['temp']
#define number of rows and columns for subplots
nrow=1
ncol=2

# make a list of all dataframes 
df_list = [df1 ,df2]
df_title= ['rain_1h','temp']
fig, axes = plt.subplots(nrow, ncol, figsize=(10,5))
i = 0
for x in axes.flatten():
  df_list[i].plot(ax=x, color='mediumvioletred')
  x.set_title(df_title[i])
  i += 1
plt.savefig("/Users/nas/Documents/MRP/dataset/images/with_outlier.png", dpi=1200)

# %%
Q1 = traffic_data.quantile(0.25)
Q3 = traffic_data.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# holiday                               0.0
# temp                               19.646
# rain_1h                               0.0
# snow_1h                               0.0
# clouds_all                           89.0
# weather_main                          5.0
# weather_description                  17.0
# ds                     1281 days 22:00:00
# traffic_volume                     3740.5
# dtype: object

# %%
traffic_data=traffic_data[~((traffic_data['temp'] <(Q1['temp']-1.5*IQR['temp'])) | (traffic_data['temp'] >(Q1['temp']+1.5*IQR['temp'])))]
traffic_data=traffic_data[~((traffic_data['traffic_volume'] <(Q1['traffic_volume']-1.5*IQR['traffic_volume'])) | (traffic_data['traffic_volume'] >(Q1['traffic_volume']+1.5*IQR['traffic_volume'])))]

# %% [markdown]
# # Prepare training and testing data

# %%
# ploting traffic data to see to see any data imbalance
traffic_data['temp'].plot()
# Out:
# <Axes: xlabel='date_time'>

# %%
traffic_data['rain_1h'].plot()
# Out:
# <Axes: xlabel='date_time'>

# %%
df1 = traffic_data['rain_1h']
df2 = traffic_data['temp']
#define number of rows and columns for subplots
nrow=1
ncol=2

# make a list of all dataframes 
df_list = [df1 ,df2]
df_title= ['rain_1h','temp']
fig, axes = plt.subplots(nrow, ncol, figsize=(10,5))
i = 0
for x in axes.flatten():
  df_list[i].plot(ax=x, color='mediumvioletred')
  x.set_title(df_title[i])
  i += 1
plt.savefig("/Users/nas/Documents/MRP/dataset/images/without_outlier.png", dpi=1200)

# %%
traffic_data
# Out:
#                      holiday    temp  rain_1h  snow_1h  clouds_all  \
# date_time
# 2012-10-02 09:00:00        1  288.28      0.0      0.0          40
# 2012-10-02 10:00:00        1  289.36      0.0      0.0          75
# 2012-10-02 11:00:00        1  289.58      0.0      0.0          90
# 2012-10-02 12:00:00        1  290.13      0.0      0.0          90
# 2012-10-02 13:00:00        1  291.14      0.0      0.0          75
# ...                      ...     ...      ...      ...         ...
# 2018-09-30 19:00:00        1  283.45      0.0      0.0          75
# 2018-09-30 20:00:00        1  282.76      0.0      0.0          90
# 2018-09-30 21:00:00        1  282.73      0.0      0.0          90
# 2018-09-30 22:00:00        1  282.09      0.0      0.0          90
# 2018-09-30 23:00:00        1  282.12      0.0      0.0          90
#
#                      weather_main  weather_description                  ds  \
# date_time
# 2012-10-02 09:00:00             1                   24 2012-10-02 09:00:00
# 2012-10-02 10:00:00             1                    2 2012-10-02 10:00:00
# 2012-10-02 11:00:00             1                   19 2012-10-02 11:00:00
# 2012-10-02 12:00:00             1                   19 2012-10-02 12:00:00
# 2012-10-02 13:00:00             1                    2 2012-10-02 13:00:00
# ...                           ...                  ...                 ...
# 2018-09-30 19:00:00             1                    2 2018-09-30 19:00:00
# 2018-09-30 20:00:00             1                   19 2018-09-30 20:00:00
# 2018-09-30 21:00:00            10                   21 2018-09-30 21:00:00
# 2018-09-30 22:00:00             1                   19 2018-09-30 22:00:00
# 2018-09-30 23:00:00             1                   19 2018-09-30 23:00:00
#
#                      traffic_volume
# date_time
# 2012-10-02 09:00:00            5545
# 2012-10-02 10:00:00            4516
# 2012-10-02 11:00:00            4767
# 2012-10-02 12:00:00            5026
# 2012-10-02 13:00:00            4918
# ...                             ...
# 2018-09-30 19:00:00            3543
# 2018-09-30 20:00:00            2781
# 2018-09-30 21:00:00            2159
# 2018-09-30 22:00:00            1450
# 2018-09-30 23:00:00             954
#
# [47008 rows x 9 columns]

# %%
split_date = '2018-01-01'
train_data = traffic_data.loc[traffic_data.index <= split_date].copy()
test_data = traffic_data.loc[traffic_data.index > split_date].copy()

# %%
def plot_series(time, series, format='-', start=0, end=None):
    plt.plot(time[start:end], series[start:end],format)
    plt.xlabel('Time')
    plt.ylabel('Traffic Volume')
    plt.grid(True)

# %%
x_train = np.array(train_data['traffic_volume'])
x_valid = np.array(test_data['traffic_volume'])

time_train = np.array(train_data['ds'])
time_valid = np.array(test_data['ds'])

plt.figure(figsize=(20,6))
plot_series(time_train, x_train)

# %%
train_data_without_ds = train_data.drop(columns=['ds'])
train_data_without_ds
test_data_without_ds = test_data.drop(columns=['ds'])
test_data_without_ds
# Out:
#                      holiday    temp  rain_1h  snow_1h  clouds_all  \
# date_time
# 2018-01-01 01:00:00        1  249.08      0.0      0.0           1
# 2018-01-01 02:00:00        1  248.86      0.0      0.0           1
# 2018-01-01 03:00:00        1  248.72      0.0      0.0           1
# 2018-01-01 04:00:00        1  248.43      0.0      0.0           1
# 2018-01-01 05:00:00        1  248.07      0.0      0.0           1
# ...                      ...     ...      ...      ...         ...
# 2018-09-30 19:00:00        1  283.45      0.0      0.0          75
# 2018-09-30 20:00:00        1  282.76      0.0      0.0          90
# 2018-09-30 21:00:00        1  282.73      0.0      0.0          90
# 2018-09-30 22:00:00        1  282.09      0.0      0.0          90
# 2018-09-30 23:00:00        1  282.12      0.0      0.0          90
#
#                      weather_main  weather_description  traffic_volume
# date_time
# 2018-01-01 01:00:00             0                   27            1408
# 2018-01-01 02:00:00             0                   27             931
# 2018-01-01 03:00:00             0                   27             585
# 2018-01-01 04:00:00             0                   27             381
# 2018-01-01 05:00:00             0                   27             434
# ...                           ...                  ...             ...
# 2018-09-30 19:00:00             1                    2            3543
# 2018-09-30 20:00:00             1                   19            2781
# 2018-09-30 21:00:00            10                   21            2159
# 2018-09-30 22:00:00             1                   19            1450
# 2018-09-30 23:00:00             1                   19             954
#
# [7628 rows x 8 columns]

# %%
x_train = np.array(train_data['traffic_volume'])
x_valid = np.array(test_data['traffic_volume'])

time_train = np.array(train_data['ds'])
time_valid = np.array(test_data['ds'])

plt.figure(figsize=(10,4))
plot_series(time_valid, x_valid)

# %%
# Values of the attribute are in different scales. For example, holiday has maximum value 1 and traffic volume let say, 2000. Since these values are totally different range, it might be hurt model learning process. To overcome this issue, we need to do data normalization or standarization.
sc = MinMaxScaler()
sc_test = MinMaxScaler()
training_data_set = sc.fit_transform(train_data_without_ds)
training_data_frame = pd.DataFrame(training_data_set)
test_data_set = sc_test.fit_transform(test_data_without_ds)
test_data_frame = pd.DataFrame(test_data_set)

# %%
# Make data for the LSTM model. I used past t-hours of data to predict the next 'n' hours data. Here window_size means window size data will be used for predicting next 'n' hours data

def df_to_x_y(data, window_size=5):
    X = []
    y = []
    for i in range(len(data)-window_size):
        row = [r for r in data[i:i+window_size]]
        X.append(row)
        label = data[i+window_size][num_of_feature-1]
        y.append(label)
    return np.array(X), np.array(y)

X, y = df_to_x_y(training_data_set,past_observation)
X.shape, y.shape
# Out:
# ((39356, 24, 8), (39356,))

# %%
# X test y Test
X_test, y_test = df_to_x_y(test_data_set, past_observation)
X_test.shape, y_test.shape
# Out:
# ((7604, 24, 8), (7604,))

# %%
# split data into train test and validation datase
from cgi import test


train_length = int(len(X)*0.9) # 80% trainging
validation_length = int(len(X)*.10) # 10% testing and rest for validation
print(train_length, validation_length, (train_length+validation_length))
X_train, y_train = X[:train_length],y[:train_length]
X_val, y_val = X[train_length:], y[train_length:]
# Out:
# 35420 3935 39355

# %%
(X_train.shape, y_train.shape), (X_val.shape, y_val.shape)
# Out:
# (((35420, 24, 8), (35420,)), ((3936, 24, 8), (3936,)))

# %%
# Define the LSTM_Model
LSTM_Model = Sequential()
# Add layers to the LSTM_Model
LSTM_Model.add(LSTM(hidden_layers_unit[0], input_shape=(past_observation, num_of_feature), return_sequences=return_sequence[0]))
LSTM_Model.add(Dropout(0.2))
LSTM_Model.add(LSTM(hidden_layers_unit[1], return_sequences=return_sequence[1]))
LSTM_Model.add(Dropout(0.2))
LSTM_Model.add(LSTM(hidden_layers_unit[2], return_sequences=return_sequence[2]))
LSTM_Model.add(Dropout(0.2))
LSTM_Model.add(LSTM(hidden_layers_unit[3], return_sequences=return_sequence[3]))
LSTM_Model.add(Dropout(0.2))
LSTM_Model.add(Dense(1))

# Compile the LSTM_Model
LSTM_Model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanAbsolutePercentageError()])
# Out:
# /Users/nas/Documents/MRP/venv/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Define the GRU_Model
GRU_Model = Sequential()
# Add layers to the GRU_Model
GRU_Model.add(GRU(hidden_layers_unit[0], input_shape=(past_observation, num_of_feature), return_sequences=return_sequence[0]))
GRU_Model.add(Dropout(0.2))
GRU_Model.add(GRU(hidden_layers_unit[1], return_sequences=return_sequence[1]))
GRU_Model.add(Dropout(0.2))
GRU_Model.add(GRU(hidden_layers_unit[2], return_sequences=return_sequence[2]))
GRU_Model.add(Dropout(0.2))
GRU_Model.add(GRU(hidden_layers_unit[3], return_sequences=return_sequence[3]))
GRU_Model.add(Dropout(0.2))
GRU_Model.add(Dense(1))

# Compile the GRU_Model
GRU_Model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanAbsolutePercentageError()])

# %%
LSTM_CheckPoint = ModelCheckpoint('/Users/nas/Documents/MRP/Traffic-Volume-Prediction-LSTM-GRU-main/model/model_lstm.keras', save_best_only=True)
GRU_CheckPoint = ModelCheckpoint('/Users/nas/Documents/MRP/Traffic-Volume-Prediction-LSTM-GRU-main/model/model_GRU.keras', save_best_only=True)
earlyStop =  tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=10, mode='min')

# %%
# Train LSTM Model
LSTM_history = LSTM_Model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=num_of_epoch, callbacks=[LSTM_CheckPoint, earlyStop], batch_size=batch_size, verbose=1)
# Out:
# Epoch 1/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 12s 74ms/step - loss: 0.1399 - mean_absolute_error: 0.3097 - mean_absolute_percentage_error: 42380.6055 - val_loss: 0.0856 - val_mean_absolute_error: 0.2565 - val_mean_absolute_percentage_error: 163.5834
# Epoch 2/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - loss: 0.0879 - mean_absolute_error: 0.2557 - mean_absolute_percentage_error: 11253.9033 - val_loss: 0.0721 - val_mean_absolute_error: 0.2283 - val_mean_absolute_percentage_error: 149.3896
# Epoch 3/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - loss: 0.0789 - mean_absolute_error: 0.2359 - mean_absolute_percentage_error: 26327.8145 - val_loss: 0.0601 - val_mean_absolute_error: 0.2027 - val_mean_absolute_percentage_error: 125.8610
# Epoch 4/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - loss: 0.0693 - mean_absolute_error: 0.2153 - mean_absolute_percentage_error: 16564.2363 - val_loss: 0.0510 - val_mean_absolute_error: 0.1826 - val_mean_absolute_percentage_error: 112.9445
# Epoch 5/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - loss: 0.0634 - mean_absolute_error: 0.2036 - mean_absolute_percentage_error: 3271.2224 - val_loss: 0.0459 - val_mean_absolute_error: 0.1704 - val_mean_absolute_percentage_error: 93.4516
# Epoch 6/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - loss: 0.0597 - mean_absolute_error: 0.1960 - mean_absolute_percentage_error: 26275.9395 - val_loss: 0.0406 - val_mean_absolute_error: 0.1621 - val_mean_absolute_percentage_error: 100.1340
# Epoch 7/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - loss: 0.0556 - mean_absolute_error: 0.1880 - mean_absolute_percentage_error: 13504.3008 - val_loss: 0.0342 - val_mean_absolute_error: 0.1469 - val_mean_absolute_percentage_error: 82.4330
# Epoch 8/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step - loss: 0.0522 - mean_absolute_error: 0.1805 - mean_absolute_percentage_error: 37125.6836 - val_loss: 0.0310 - val_mean_absolute_error: 0.1416 - val_mean_absolute_percentage_error: 81.3735
# Epoch 9/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - loss: 0.0476 - mean_absolute_error: 0.1702 - mean_absolute_percentage_error: 7169.7100 - val_loss: 0.0288 - val_mean_absolute_error: 0.1313 - val_mean_absolute_percentage_error: 61.9903
# Epoch 10/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 103ms/step - loss: 0.0437 - mean_absolute_error: 0.1623 - mean_absolute_percentage_error: 5555.0254 - val_loss: 0.0247 - val_mean_absolute_error: 0.1244 - val_mean_absolute_percentage_error: 66.3952
# Epoch 11/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - loss: 0.0419 - mean_absolute_error: 0.1586 - mean_absolute_percentage_error: 5877.9595 - val_loss: 0.0225 - val_mean_absolute_error: 0.1148 - val_mean_absolute_percentage_error: 49.2657
# Epoch 12/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - loss: 0.0401 - mean_absolute_error: 0.1539 - mean_absolute_percentage_error: 5030.1655 - val_loss: 0.0215 - val_mean_absolute_error: 0.1132 - val_mean_absolute_percentage_error: 50.6001
# Epoch 13/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - loss: 0.0376 - mean_absolute_error: 0.1490 - mean_absolute_percentage_error: 4450.0195 - val_loss: 0.0197 - val_mean_absolute_error: 0.1103 - val_mean_absolute_percentage_error: 55.2218
# Epoch 14/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 15s 107ms/step - loss: 0.0354 - mean_absolute_error: 0.1446 - mean_absolute_percentage_error: 11287.4512 - val_loss: 0.0180 - val_mean_absolute_error: 0.1027 - val_mean_absolute_percentage_error: 43.5602
# Epoch 15/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - loss: 0.0333 - mean_absolute_error: 0.1394 - mean_absolute_percentage_error: 31951.2090 - val_loss: 0.0159 - val_mean_absolute_error: 0.0966 - val_mean_absolute_percentage_error: 41.0874
# Epoch 16/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - loss: 0.0312 - mean_absolute_error: 0.1345 - mean_absolute_percentage_error: 6473.5913 - val_loss: 0.0150 - val_mean_absolute_error: 0.0936 - val_mean_absolute_percentage_error: 37.9452
# Epoch 17/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - loss: 0.0304 - mean_absolute_error: 0.1327 - mean_absolute_percentage_error: 27045.3945 - val_loss: 0.0143 - val_mean_absolute_error: 0.0917 - val_mean_absolute_percentage_error: 40.0448
# Epoch 18/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - loss: 0.0284 - mean_absolute_error: 0.1279 - mean_absolute_percentage_error: 10656.6660 - val_loss: 0.0124 - val_mean_absolute_error: 0.0844 - val_mean_absolute_percentage_error: 36.7835
# Epoch 19/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - loss: 0.0273 - mean_absolute_error: 0.1259 - mean_absolute_percentage_error: 4342.0259 - val_loss: 0.0117 - val_mean_absolute_error: 0.0820 - val_mean_absolute_percentage_error: 35.5203
# Epoch 20/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - loss: 0.0262 - mean_absolute_error: 0.1229 - mean_absolute_percentage_error: 12960.5869 - val_loss: 0.0107 - val_mean_absolute_error: 0.0777 - val_mean_absolute_percentage_error: 30.4604
# Epoch 21/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0243 - mean_absolute_error: 0.1186 - mean_absolute_percentage_error: 12081.7236 - val_loss: 0.0097 - val_mean_absolute_error: 0.0745 - val_mean_absolute_percentage_error: 33.0401
# Epoch 22/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - loss: 0.0236 - mean_absolute_error: 0.1163 - mean_absolute_percentage_error: 12060.9023 - val_loss: 0.0095 - val_mean_absolute_error: 0.0736 - val_mean_absolute_percentage_error: 29.5358
# Epoch 23/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 103ms/step - loss: 0.0228 - mean_absolute_error: 0.1141 - mean_absolute_percentage_error: 11333.7178 - val_loss: 0.0088 - val_mean_absolute_error: 0.0698 - val_mean_absolute_percentage_error: 26.0973
# Epoch 24/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0214 - mean_absolute_error: 0.1100 - mean_absolute_percentage_error: 1022.7747 - val_loss: 0.0079 - val_mean_absolute_error: 0.0666 - val_mean_absolute_percentage_error: 28.4012
# Epoch 25/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 92ms/step - loss: 0.0205 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 914.3638 - val_loss: 0.0078 - val_mean_absolute_error: 0.0654 - val_mean_absolute_percentage_error: 24.4897
# Epoch 26/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0204 - mean_absolute_error: 0.1076 - mean_absolute_percentage_error: 3781.4351 - val_loss: 0.0076 - val_mean_absolute_error: 0.0652 - val_mean_absolute_percentage_error: 28.3633
# Epoch 27/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - loss: 0.0194 - mean_absolute_error: 0.1045 - mean_absolute_percentage_error: 4677.6167 - val_loss: 0.0071 - val_mean_absolute_error: 0.0629 - val_mean_absolute_percentage_error: 26.3171
# Epoch 28/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - loss: 0.0188 - mean_absolute_error: 0.1030 - mean_absolute_percentage_error: 7564.5708 - val_loss: 0.0069 - val_mean_absolute_error: 0.0612 - val_mean_absolute_percentage_error: 22.9481
# Epoch 29/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 15s 107ms/step - loss: 0.0185 - mean_absolute_error: 0.1017 - mean_absolute_percentage_error: 10305.0547 - val_loss: 0.0067 - val_mean_absolute_error: 0.0606 - val_mean_absolute_percentage_error: 23.3378
# Epoch 30/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - loss: 0.0177 - mean_absolute_error: 0.0995 - mean_absolute_percentage_error: 2442.4578 - val_loss: 0.0066 - val_mean_absolute_error: 0.0606 - val_mean_absolute_percentage_error: 27.4888
# Epoch 31/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 15s 109ms/step - loss: 0.0173 - mean_absolute_error: 0.0978 - mean_absolute_percentage_error: 570.8008 - val_loss: 0.0063 - val_mean_absolute_error: 0.0592 - val_mean_absolute_percentage_error: 23.8257
# Epoch 32/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 92ms/step - loss: 0.0166 - mean_absolute_error: 0.0956 - mean_absolute_percentage_error: 5343.6426 - val_loss: 0.0060 - val_mean_absolute_error: 0.0573 - val_mean_absolute_percentage_error: 22.7184
# Epoch 33/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step - loss: 0.0167 - mean_absolute_error: 0.0961 - mean_absolute_percentage_error: 3851.7747 - val_loss: 0.0061 - val_mean_absolute_error: 0.0588 - val_mean_absolute_percentage_error: 22.6545
# Epoch 34/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 92ms/step - loss: 0.0161 - mean_absolute_error: 0.0939 - mean_absolute_percentage_error: 2346.1919 - val_loss: 0.0061 - val_mean_absolute_error: 0.0583 - val_mean_absolute_percentage_error: 21.8329
# Epoch 35/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - loss: 0.0156 - mean_absolute_error: 0.0925 - mean_absolute_percentage_error: 22496.9141 - val_loss: 0.0060 - val_mean_absolute_error: 0.0579 - val_mean_absolute_percentage_error: 22.3517
# Epoch 36/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - loss: 0.0152 - mean_absolute_error: 0.0912 - mean_absolute_percentage_error: 1832.7891 - val_loss: 0.0058 - val_mean_absolute_error: 0.0573 - val_mean_absolute_percentage_error: 21.8997
# Epoch 37/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step - loss: 0.0147 - mean_absolute_error: 0.0896 - mean_absolute_percentage_error: 9755.8428 - val_loss: 0.0055 - val_mean_absolute_error: 0.0548 - val_mean_absolute_percentage_error: 22.1298
# Epoch 38/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 103ms/step - loss: 0.0147 - mean_absolute_error: 0.0894 - mean_absolute_percentage_error: 6358.4209 - val_loss: 0.0055 - val_mean_absolute_error: 0.0544 - val_mean_absolute_percentage_error: 18.9727
# Epoch 39/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 15s 109ms/step - loss: 0.0143 - mean_absolute_error: 0.0878 - mean_absolute_percentage_error: 6330.6577 - val_loss: 0.0053 - val_mean_absolute_error: 0.0536 - val_mean_absolute_percentage_error: 19.6348
# Epoch 40/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 15s 108ms/step - loss: 0.0140 - mean_absolute_error: 0.0868 - mean_absolute_percentage_error: 2801.5518 - val_loss: 0.0052 - val_mean_absolute_error: 0.0530 - val_mean_absolute_percentage_error: 20.7401
# Epoch 41/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - loss: 0.0136 - mean_absolute_error: 0.0853 - mean_absolute_percentage_error: 1588.7223 - val_loss: 0.0053 - val_mean_absolute_error: 0.0541 - val_mean_absolute_percentage_error: 22.2664
# Epoch 42/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - loss: 0.0134 - mean_absolute_error: 0.0846 - mean_absolute_percentage_error: 1618.8583 - val_loss: 0.0052 - val_mean_absolute_error: 0.0532 - val_mean_absolute_percentage_error: 20.4969
# Epoch 43/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - loss: 0.0133 - mean_absolute_error: 0.0846 - mean_absolute_percentage_error: 4290.4395 - val_loss: 0.0052 - val_mean_absolute_error: 0.0534 - val_mean_absolute_percentage_error: 21.2614
# Epoch 44/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 15s 105ms/step - loss: 0.0130 - mean_absolute_error: 0.0828 - mean_absolute_percentage_error: 6414.5830 - val_loss: 0.0050 - val_mean_absolute_error: 0.0523 - val_mean_absolute_percentage_error: 19.1088
# Epoch 45/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0128 - mean_absolute_error: 0.0823 - mean_absolute_percentage_error: 781.3109 - val_loss: 0.0050 - val_mean_absolute_error: 0.0521 - val_mean_absolute_percentage_error: 21.5517
# Epoch 46/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - loss: 0.0128 - mean_absolute_error: 0.0825 - mean_absolute_percentage_error: 3348.0420 - val_loss: 0.0049 - val_mean_absolute_error: 0.0511 - val_mean_absolute_percentage_error: 18.2718
# Epoch 47/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - loss: 0.0128 - mean_absolute_error: 0.0815 - mean_absolute_percentage_error: 2605.1853 - val_loss: 0.0049 - val_mean_absolute_error: 0.0507 - val_mean_absolute_percentage_error: 17.9813
# Epoch 48/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 15s 111ms/step - loss: 0.0123 - mean_absolute_error: 0.0807 - mean_absolute_percentage_error: 8996.3232 - val_loss: 0.0051 - val_mean_absolute_error: 0.0525 - val_mean_absolute_percentage_error: 17.4072
# Epoch 49/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0123 - mean_absolute_error: 0.0804 - mean_absolute_percentage_error: 6959.1763 - val_loss: 0.0049 - val_mean_absolute_error: 0.0511 - val_mean_absolute_percentage_error: 19.0228
# Epoch 50/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - loss: 0.0120 - mean_absolute_error: 0.0798 - mean_absolute_percentage_error: 3013.7283 - val_loss: 0.0048 - val_mean_absolute_error: 0.0502 - val_mean_absolute_percentage_error: 18.5773
# Epoch 51/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - loss: 0.0121 - mean_absolute_error: 0.0795 - mean_absolute_percentage_error: 1776.7246 - val_loss: 0.0048 - val_mean_absolute_error: 0.0508 - val_mean_absolute_percentage_error: 18.2284
# Epoch 52/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - loss: 0.0120 - mean_absolute_error: 0.0786 - mean_absolute_percentage_error: 161.8534 - val_loss: 0.0048 - val_mean_absolute_error: 0.0507 - val_mean_absolute_percentage_error: 17.4806
# Epoch 53/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - loss: 0.0116 - mean_absolute_error: 0.0778 - mean_absolute_percentage_error: 25843.3945 - val_loss: 0.0047 - val_mean_absolute_error: 0.0497 - val_mean_absolute_percentage_error: 17.1538
# Epoch 54/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - loss: 0.0115 - mean_absolute_error: 0.0771 - mean_absolute_percentage_error: 6905.1162 - val_loss: 0.0047 - val_mean_absolute_error: 0.0501 - val_mean_absolute_percentage_error: 16.9353
# Epoch 55/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 16s 113ms/step - loss: 0.0112 - mean_absolute_error: 0.0763 - mean_absolute_percentage_error: 6467.0264 - val_loss: 0.0046 - val_mean_absolute_error: 0.0496 - val_mean_absolute_percentage_error: 17.8608
# Epoch 56/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 15s 105ms/step - loss: 0.0112 - mean_absolute_error: 0.0764 - mean_absolute_percentage_error: 3196.7461 - val_loss: 0.0047 - val_mean_absolute_error: 0.0502 - val_mean_absolute_percentage_error: 18.1862
# Epoch 57/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - loss: 0.0113 - mean_absolute_error: 0.0764 - mean_absolute_percentage_error: 8050.7690 - val_loss: 0.0047 - val_mean_absolute_error: 0.0508 - val_mean_absolute_percentage_error: 20.6970
# Epoch 58/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - loss: 0.0113 - mean_absolute_error: 0.0772 - mean_absolute_percentage_error: 1914.9302 - val_loss: 0.0046 - val_mean_absolute_error: 0.0495 - val_mean_absolute_percentage_error: 19.0748
# Epoch 59/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0110 - mean_absolute_error: 0.0752 - mean_absolute_percentage_error: 8618.0566 - val_loss: 0.0047 - val_mean_absolute_error: 0.0499 - val_mean_absolute_percentage_error: 17.0067
# Epoch 60/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - loss: 0.0108 - mean_absolute_error: 0.0748 - mean_absolute_percentage_error: 12719.3369 - val_loss: 0.0046 - val_mean_absolute_error: 0.0493 - val_mean_absolute_percentage_error: 18.4402
# Epoch 61/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 103ms/step - loss: 0.0109 - mean_absolute_error: 0.0751 - mean_absolute_percentage_error: 3427.9248 - val_loss: 0.0047 - val_mean_absolute_error: 0.0502 - val_mean_absolute_percentage_error: 17.5971
# Epoch 62/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0108 - mean_absolute_error: 0.0746 - mean_absolute_percentage_error: 7259.0684 - val_loss: 0.0045 - val_mean_absolute_error: 0.0480 - val_mean_absolute_percentage_error: 17.4899
# Epoch 63/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 15s 108ms/step - loss: 0.0107 - mean_absolute_error: 0.0742 - mean_absolute_percentage_error: 5724.8574 - val_loss: 0.0045 - val_mean_absolute_error: 0.0482 - val_mean_absolute_percentage_error: 16.5886
# Epoch 64/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 16s 115ms/step - loss: 0.0108 - mean_absolute_error: 0.0745 - mean_absolute_percentage_error: 2663.7336 - val_loss: 0.0045 - val_mean_absolute_error: 0.0496 - val_mean_absolute_percentage_error: 19.0775
# Epoch 65/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 103ms/step - loss: 0.0107 - mean_absolute_error: 0.0738 - mean_absolute_percentage_error: 6671.6060 - val_loss: 0.0046 - val_mean_absolute_error: 0.0501 - val_mean_absolute_percentage_error: 16.3785
# Epoch 66/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0107 - mean_absolute_error: 0.0743 - mean_absolute_percentage_error: 20106.6699 - val_loss: 0.0045 - val_mean_absolute_error: 0.0487 - val_mean_absolute_percentage_error: 16.0410
# Epoch 67/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - loss: 0.0104 - mean_absolute_error: 0.0733 - mean_absolute_percentage_error: 1705.0249 - val_loss: 0.0045 - val_mean_absolute_error: 0.0494 - val_mean_absolute_percentage_error: 19.6539
# Epoch 68/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - loss: 0.0103 - mean_absolute_error: 0.0732 - mean_absolute_percentage_error: 2118.1106 - val_loss: 0.0044 - val_mean_absolute_error: 0.0480 - val_mean_absolute_percentage_error: 15.9664
# Epoch 69/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0102 - mean_absolute_error: 0.0718 - mean_absolute_percentage_error: 1941.4584 - val_loss: 0.0045 - val_mean_absolute_error: 0.0484 - val_mean_absolute_percentage_error: 15.6404
# Epoch 70/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0100 - mean_absolute_error: 0.0717 - mean_absolute_percentage_error: 434.9410 - val_loss: 0.0044 - val_mean_absolute_error: 0.0484 - val_mean_absolute_percentage_error: 17.6626
# Epoch 71/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - loss: 0.0101 - mean_absolute_error: 0.0721 - mean_absolute_percentage_error: 798.4131 - val_loss: 0.0045 - val_mean_absolute_error: 0.0487 - val_mean_absolute_percentage_error: 16.6482
# Epoch 72/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - loss: 0.0102 - mean_absolute_error: 0.0727 - mean_absolute_percentage_error: 7632.7124 - val_loss: 0.0046 - val_mean_absolute_error: 0.0492 - val_mean_absolute_percentage_error: 14.9144
# Epoch 73/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - loss: 0.0100 - mean_absolute_error: 0.0714 - mean_absolute_percentage_error: 4389.5854 - val_loss: 0.0044 - val_mean_absolute_error: 0.0484 - val_mean_absolute_percentage_error: 17.5605
# Epoch 74/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - loss: 0.0101 - mean_absolute_error: 0.0722 - mean_absolute_percentage_error: 3407.2168 - val_loss: 0.0044 - val_mean_absolute_error: 0.0481 - val_mean_absolute_percentage_error: 16.1594
# Epoch 75/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - loss: 0.0103 - mean_absolute_error: 0.0723 - mean_absolute_percentage_error: 10205.5264 - val_loss: 0.0043 - val_mean_absolute_error: 0.0477 - val_mean_absolute_percentage_error: 17.2155
# Epoch 76/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - loss: 0.0099 - mean_absolute_error: 0.0712 - mean_absolute_percentage_error: 14803.1777 - val_loss: 0.0042 - val_mean_absolute_error: 0.0470 - val_mean_absolute_percentage_error: 17.4619
# Epoch 77/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - loss: 0.0097 - mean_absolute_error: 0.0704 - mean_absolute_percentage_error: 1603.3412 - val_loss: 0.0043 - val_mean_absolute_error: 0.0469 - val_mean_absolute_percentage_error: 16.9421
# Epoch 78/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - loss: 0.0096 - mean_absolute_error: 0.0701 - mean_absolute_percentage_error: 2622.2170 - val_loss: 0.0042 - val_mean_absolute_error: 0.0463 - val_mean_absolute_percentage_error: 15.5047
# Epoch 79/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0099 - mean_absolute_error: 0.0708 - mean_absolute_percentage_error: 3983.3489 - val_loss: 0.0042 - val_mean_absolute_error: 0.0468 - val_mean_absolute_percentage_error: 17.2663
# Epoch 80/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0098 - mean_absolute_error: 0.0713 - mean_absolute_percentage_error: 915.2574 - val_loss: 0.0042 - val_mean_absolute_error: 0.0461 - val_mean_absolute_percentage_error: 16.8991
# Epoch 81/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0094 - mean_absolute_error: 0.0697 - mean_absolute_percentage_error: 16698.8145 - val_loss: 0.0043 - val_mean_absolute_error: 0.0470 - val_mean_absolute_percentage_error: 16.5567
# Epoch 82/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - loss: 0.0094 - mean_absolute_error: 0.0692 - mean_absolute_percentage_error: 1509.6393 - val_loss: 0.0042 - val_mean_absolute_error: 0.0472 - val_mean_absolute_percentage_error: 16.1641
# Epoch 83/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0097 - mean_absolute_error: 0.0704 - mean_absolute_percentage_error: 10322.1387 - val_loss: 0.0043 - val_mean_absolute_error: 0.0474 - val_mean_absolute_percentage_error: 15.6214
# Epoch 84/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0095 - mean_absolute_error: 0.0695 - mean_absolute_percentage_error: 2510.8853 - val_loss: 0.0042 - val_mean_absolute_error: 0.0460 - val_mean_absolute_percentage_error: 14.6863
# Epoch 85/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - loss: 0.0093 - mean_absolute_error: 0.0689 - mean_absolute_percentage_error: 10294.4102 - val_loss: 0.0041 - val_mean_absolute_error: 0.0461 - val_mean_absolute_percentage_error: 15.7258
# Epoch 86/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0094 - mean_absolute_error: 0.0693 - mean_absolute_percentage_error: 4432.9922 - val_loss: 0.0042 - val_mean_absolute_error: 0.0468 - val_mean_absolute_percentage_error: 17.3741
# Epoch 87/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0096 - mean_absolute_error: 0.0697 - mean_absolute_percentage_error: 2967.0608 - val_loss: 0.0042 - val_mean_absolute_error: 0.0472 - val_mean_absolute_percentage_error: 18.7818
# Epoch 88/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - loss: 0.0096 - mean_absolute_error: 0.0696 - mean_absolute_percentage_error: 4453.5811 - val_loss: 0.0041 - val_mean_absolute_error: 0.0463 - val_mean_absolute_percentage_error: 18.0045
# Epoch 89/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - loss: 0.0094 - mean_absolute_error: 0.0690 - mean_absolute_percentage_error: 620.4335 - val_loss: 0.0041 - val_mean_absolute_error: 0.0458 - val_mean_absolute_percentage_error: 15.0311
# Epoch 90/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0093 - mean_absolute_error: 0.0685 - mean_absolute_percentage_error: 2967.3992 - val_loss: 0.0042 - val_mean_absolute_error: 0.0468 - val_mean_absolute_percentage_error: 14.5249
# Epoch 91/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - loss: 0.0096 - mean_absolute_error: 0.0695 - mean_absolute_percentage_error: 8801.4482 - val_loss: 0.0041 - val_mean_absolute_error: 0.0465 - val_mean_absolute_percentage_error: 15.5621
# Epoch 92/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0093 - mean_absolute_error: 0.0684 - mean_absolute_percentage_error: 411.8882 - val_loss: 0.0041 - val_mean_absolute_error: 0.0458 - val_mean_absolute_percentage_error: 16.7225
# Epoch 93/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0092 - mean_absolute_error: 0.0681 - mean_absolute_percentage_error: 6045.9937 - val_loss: 0.0041 - val_mean_absolute_error: 0.0469 - val_mean_absolute_percentage_error: 17.9872
# Epoch 94/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - loss: 0.0092 - mean_absolute_error: 0.0685 - mean_absolute_percentage_error: 323.7969 - val_loss: 0.0042 - val_mean_absolute_error: 0.0462 - val_mean_absolute_percentage_error: 14.6770
# Epoch 95/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - loss: 0.0093 - mean_absolute_error: 0.0686 - mean_absolute_percentage_error: 3250.8379 - val_loss: 0.0042 - val_mean_absolute_error: 0.0470 - val_mean_absolute_percentage_error: 17.8882
# Epoch 96/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - loss: 0.0093 - mean_absolute_error: 0.0688 - mean_absolute_percentage_error: 2424.0322 - val_loss: 0.0040 - val_mean_absolute_error: 0.0454 - val_mean_absolute_percentage_error: 15.4199
# Epoch 97/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0091 - mean_absolute_error: 0.0676 - mean_absolute_percentage_error: 6459.5337 - val_loss: 0.0041 - val_mean_absolute_error: 0.0457 - val_mean_absolute_percentage_error: 14.7919
# Epoch 98/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0088 - mean_absolute_error: 0.0672 - mean_absolute_percentage_error: 6418.6494 - val_loss: 0.0040 - val_mean_absolute_error: 0.0455 - val_mean_absolute_percentage_error: 15.7133
# Epoch 99/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 103ms/step - loss: 0.0090 - mean_absolute_error: 0.0674 - mean_absolute_percentage_error: 670.2495 - val_loss: 0.0041 - val_mean_absolute_error: 0.0467 - val_mean_absolute_percentage_error: 17.6987
# Epoch 100/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0092 - mean_absolute_error: 0.0677 - mean_absolute_percentage_error: 5345.0811 - val_loss: 0.0040 - val_mean_absolute_error: 0.0451 - val_mean_absolute_percentage_error: 16.3898
# Epoch 101/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - loss: 0.0092 - mean_absolute_error: 0.0675 - mean_absolute_percentage_error: 13225.0186 - val_loss: 0.0041 - val_mean_absolute_error: 0.0466 - val_mean_absolute_percentage_error: 18.5525
# Epoch 102/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - loss: 0.0089 - mean_absolute_error: 0.0674 - mean_absolute_percentage_error: 3717.8203 - val_loss: 0.0041 - val_mean_absolute_error: 0.0463 - val_mean_absolute_percentage_error: 16.3371
# Epoch 103/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0089 - mean_absolute_error: 0.0673 - mean_absolute_percentage_error: 1571.0485 - val_loss: 0.0041 - val_mean_absolute_error: 0.0461 - val_mean_absolute_percentage_error: 15.3655
# Epoch 104/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - loss: 0.0090 - mean_absolute_error: 0.0674 - mean_absolute_percentage_error: 6385.0552 - val_loss: 0.0040 - val_mean_absolute_error: 0.0450 - val_mean_absolute_percentage_error: 14.4612
# Epoch 105/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0090 - mean_absolute_error: 0.0674 - mean_absolute_percentage_error: 6805.8262 - val_loss: 0.0039 - val_mean_absolute_error: 0.0440 - val_mean_absolute_percentage_error: 15.6549
# Epoch 106/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - loss: 0.0089 - mean_absolute_error: 0.0671 - mean_absolute_percentage_error: 6515.0645 - val_loss: 0.0040 - val_mean_absolute_error: 0.0456 - val_mean_absolute_percentage_error: 16.1212
# Epoch 107/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - loss: 0.0087 - mean_absolute_error: 0.0668 - mean_absolute_percentage_error: 12729.4736 - val_loss: 0.0040 - val_mean_absolute_error: 0.0455 - val_mean_absolute_percentage_error: 16.1367
# Epoch 108/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - loss: 0.0090 - mean_absolute_error: 0.0671 - mean_absolute_percentage_error: 630.3570 - val_loss: 0.0039 - val_mean_absolute_error: 0.0442 - val_mean_absolute_percentage_error: 15.3608
# Epoch 109/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - loss: 0.0089 - mean_absolute_error: 0.0670 - mean_absolute_percentage_error: 1434.6952 - val_loss: 0.0039 - val_mean_absolute_error: 0.0448 - val_mean_absolute_percentage_error: 14.7815
# Epoch 110/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0090 - mean_absolute_error: 0.0672 - mean_absolute_percentage_error: 9745.4688 - val_loss: 0.0040 - val_mean_absolute_error: 0.0449 - val_mean_absolute_percentage_error: 13.9829
# Epoch 111/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 104ms/step - loss: 0.0087 - mean_absolute_error: 0.0664 - mean_absolute_percentage_error: 9179.6494 - val_loss: 0.0039 - val_mean_absolute_error: 0.0454 - val_mean_absolute_percentage_error: 17.0100
# Epoch 112/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - loss: 0.0089 - mean_absolute_error: 0.0667 - mean_absolute_percentage_error: 2771.6816 - val_loss: 0.0040 - val_mean_absolute_error: 0.0458 - val_mean_absolute_percentage_error: 16.8464
# Epoch 113/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - loss: 0.0087 - mean_absolute_error: 0.0660 - mean_absolute_percentage_error: 2711.7546 - val_loss: 0.0039 - val_mean_absolute_error: 0.0442 - val_mean_absolute_percentage_error: 14.9064
# Epoch 114/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0087 - mean_absolute_error: 0.0660 - mean_absolute_percentage_error: 2127.2041 - val_loss: 0.0039 - val_mean_absolute_error: 0.0455 - val_mean_absolute_percentage_error: 17.2239
# Epoch 115/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - loss: 0.0085 - mean_absolute_error: 0.0657 - mean_absolute_percentage_error: 1056.0209 - val_loss: 0.0038 - val_mean_absolute_error: 0.0444 - val_mean_absolute_percentage_error: 15.3815
# Epoch 116/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0084 - mean_absolute_error: 0.0654 - mean_absolute_percentage_error: 3707.2852 - val_loss: 0.0039 - val_mean_absolute_error: 0.0438 - val_mean_absolute_percentage_error: 15.3997
# Epoch 117/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - loss: 0.0085 - mean_absolute_error: 0.0655 - mean_absolute_percentage_error: 4355.8101 - val_loss: 0.0039 - val_mean_absolute_error: 0.0457 - val_mean_absolute_percentage_error: 17.5924
# Epoch 118/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0087 - mean_absolute_error: 0.0662 - mean_absolute_percentage_error: 13964.0791 - val_loss: 0.0038 - val_mean_absolute_error: 0.0434 - val_mean_absolute_percentage_error: 14.6508
# Epoch 119/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0085 - mean_absolute_error: 0.0654 - mean_absolute_percentage_error: 2126.6353 - val_loss: 0.0038 - val_mean_absolute_error: 0.0440 - val_mean_absolute_percentage_error: 13.7414
# Epoch 120/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - loss: 0.0086 - mean_absolute_error: 0.0656 - mean_absolute_percentage_error: 902.9415 - val_loss: 0.0039 - val_mean_absolute_error: 0.0449 - val_mean_absolute_percentage_error: 16.1634
# Epoch 121/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0085 - mean_absolute_error: 0.0653 - mean_absolute_percentage_error: 7967.0625 - val_loss: 0.0038 - val_mean_absolute_error: 0.0432 - val_mean_absolute_percentage_error: 14.8026
# Epoch 122/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - loss: 0.0084 - mean_absolute_error: 0.0654 - mean_absolute_percentage_error: 686.9161 - val_loss: 0.0039 - val_mean_absolute_error: 0.0445 - val_mean_absolute_percentage_error: 16.9683
# Epoch 123/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - loss: 0.0085 - mean_absolute_error: 0.0654 - mean_absolute_percentage_error: 3615.6619 - val_loss: 0.0038 - val_mean_absolute_error: 0.0443 - val_mean_absolute_percentage_error: 16.4834
# Epoch 124/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0084 - mean_absolute_error: 0.0650 - mean_absolute_percentage_error: 2709.0828 - val_loss: 0.0039 - val_mean_absolute_error: 0.0453 - val_mean_absolute_percentage_error: 17.8196
# Epoch 125/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - loss: 0.0084 - mean_absolute_error: 0.0651 - mean_absolute_percentage_error: 4048.0713 - val_loss: 0.0038 - val_mean_absolute_error: 0.0439 - val_mean_absolute_percentage_error: 14.4843
# Epoch 126/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - loss: 0.0085 - mean_absolute_error: 0.0651 - mean_absolute_percentage_error: 4450.0571 - val_loss: 0.0038 - val_mean_absolute_error: 0.0440 - val_mean_absolute_percentage_error: 16.3465
# Epoch 127/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - loss: 0.0086 - mean_absolute_error: 0.0655 - mean_absolute_percentage_error: 4437.8438 - val_loss: 0.0038 - val_mean_absolute_error: 0.0436 - val_mean_absolute_percentage_error: 13.8830
# Epoch 128/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - loss: 0.0085 - mean_absolute_error: 0.0651 - mean_absolute_percentage_error: 4108.5620 - val_loss: 0.0038 - val_mean_absolute_error: 0.0434 - val_mean_absolute_percentage_error: 14.3450
# Epoch 129/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0084 - mean_absolute_error: 0.0654 - mean_absolute_percentage_error: 5277.5659 - val_loss: 0.0038 - val_mean_absolute_error: 0.0435 - val_mean_absolute_percentage_error: 14.0475
# Epoch 130/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0088 - mean_absolute_error: 0.0658 - mean_absolute_percentage_error: 1134.1119 - val_loss: 0.0038 - val_mean_absolute_error: 0.0437 - val_mean_absolute_percentage_error: 14.2077
# Epoch 131/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - loss: 0.0086 - mean_absolute_error: 0.0654 - mean_absolute_percentage_error: 12736.4922 - val_loss: 0.0038 - val_mean_absolute_error: 0.0436 - val_mean_absolute_percentage_error: 15.3736

# %%
# Train GRU Model
GRU_history = GRU_Model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=num_of_epoch, callbacks=[GRU_CheckPoint, earlyStop], batch_size=batch_size, verbose=1)
# Out:
# Epoch 1/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 16s 97ms/step - loss: 0.1566 - mean_absolute_error: 0.3243 - mean_absolute_percentage_error: 39480.2109 - val_loss: 0.0674 - val_mean_absolute_error: 0.2263 - val_mean_absolute_percentage_error: 132.8177
# Epoch 2/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - loss: 0.0697 - mean_absolute_error: 0.2232 - mean_absolute_percentage_error: 19490.1074 - val_loss: 0.0400 - val_mean_absolute_error: 0.1593 - val_mean_absolute_percentage_error: 88.8585
# Epoch 3/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - loss: 0.0504 - mean_absolute_error: 0.1782 - mean_absolute_percentage_error: 8209.9893 - val_loss: 0.0330 - val_mean_absolute_error: 0.1401 - val_mean_absolute_percentage_error: 65.2739
# Epoch 4/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - loss: 0.0434 - mean_absolute_error: 0.1631 - mean_absolute_percentage_error: 10899.9814 - val_loss: 0.0258 - val_mean_absolute_error: 0.1272 - val_mean_absolute_percentage_error: 65.5212
# Epoch 5/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - loss: 0.0378 - mean_absolute_error: 0.1515 - mean_absolute_percentage_error: 10710.1094 - val_loss: 0.0218 - val_mean_absolute_error: 0.1149 - val_mean_absolute_percentage_error: 52.2985
# Epoch 6/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - loss: 0.0328 - mean_absolute_error: 0.1404 - mean_absolute_percentage_error: 5854.0723 - val_loss: 0.0170 - val_mean_absolute_error: 0.1046 - val_mean_absolute_percentage_error: 53.2644
# Epoch 7/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - loss: 0.0296 - mean_absolute_error: 0.1323 - mean_absolute_percentage_error: 12440.6201 - val_loss: 0.0143 - val_mean_absolute_error: 0.0929 - val_mean_absolute_percentage_error: 38.8454
# Epoch 8/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - loss: 0.0266 - mean_absolute_error: 0.1242 - mean_absolute_percentage_error: 2551.6702 - val_loss: 0.0115 - val_mean_absolute_error: 0.0826 - val_mean_absolute_percentage_error: 38.8114
# Epoch 9/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0241 - mean_absolute_error: 0.1171 - mean_absolute_percentage_error: 4590.7397 - val_loss: 0.0102 - val_mean_absolute_error: 0.0778 - val_mean_absolute_percentage_error: 36.2186
# Epoch 10/500
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - loss: 0.0226 - mean_absolute_error: 0.1137 - mean_absolute_percentage_error: 7688.4131 - val_loss: 0.0094 - val_mean_absolute_error: 0.0724 - val_mean_absolute_percentage_error: 29.8167

# %%
# summarize history for loss
fig, ax = plt.subplots(1,2, figsize=(16,8))
ax[0].plot(LSTM_history.history['loss'], color='red')
ax[0].plot(LSTM_history.history['val_loss'], color='crimson')
ax[0].set_title('LSTM Model Loss')
ax[0].set_ylabel('Loss')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Training Loss', 'Validation Loss'], loc='upper right')

ax[1].plot(GRU_history.history['loss'], color='red')
ax[1].plot(GRU_history.history['val_loss'], color='crimson')
ax[1].set_title('GRU Model Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Training Loss', 'Validation Loss'], loc='upper right')
plt.savefig("/Users/nas/Documents/MRP/dataset/images/training_loss.png", dpi=1200)
plt.show()

# %%
# summarize history for loss
fig, ax = plt.subplots(2,2, figsize=(16,8))
ax[0][0].plot(LSTM_history.history['mean_absolute_error'], color='red')
ax[0][0].plot(LSTM_history.history['val_mean_absolute_error'], color='crimson')
ax[0][0].set_title('Mean Absolute Error (LSTM)')
ax[0][0].set_ylabel('Error')
ax[0][0].set_xlabel('Epoch')
ax[0][0].legend(['Training Error', 'Validation Error'], loc='upper right')

ax[0][1].plot(LSTM_history.history['mean_absolute_percentage_error'], color='red')
ax[0][1].plot(LSTM_history.history['val_mean_absolute_percentage_error'], color='crimson')
ax[0][1].set_title('Mean Absolute Percentatge Error (LSTM)')
ax[0][1].set_ylabel('Error')
ax[0][1].set_xlabel('Epoch')
ax[0][1].legend(['Training Error', 'Validation Error'], loc='upper right')


ax[1][0].plot(GRU_history.history['mean_absolute_error'], color='orangered')
ax[1][0].plot(GRU_history.history['val_mean_absolute_error'], color='firebrick')
ax[1][0].set_title('Mean Absolute Error (GRU)')
ax[1][0].set_ylabel('Loss')
ax[1][0].set_xlabel('Epoch')
ax[1][0].legend(['Training Loss', 'Validation Loss'], loc='upper right')

ax[1][1].plot(GRU_history.history['mean_absolute_percentage_error'], color='orangered')
ax[1][1].plot(GRU_history.history['val_mean_absolute_percentage_error'], color='firebrick')
ax[1][1].set_title('Mean Absolute Percentatge Error (GRU)')
ax[1][1].set_ylabel('Error')
ax[1][1].set_xlabel('Epoch')
ax[1][1].legend(['Training Error', 'Validation Error'], loc='upper right')
fig.tight_layout()
plt.savefig("/Users/nas/Documents/MRP/dataset/images/mean_absolute_error_loss.png", dpi=1200)
plt.show()

# %%
from tensorflow.keras.models import load_model
lstm_model = load_model('/Users/nas/Documents/MRP/Traffic-Volume-Prediction-LSTM-GRU-main/model/model_lstm.keras')
gru_model = load_model('/Users/nas/Documents/MRP/Traffic-Volume-Prediction-LSTM-GRU-main/model/model_gru.keras')

# %%
lstm_prediction = lstm_model.predict(X_test)
gru_prediction = gru_model.predict(X_test)
# Out:
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step

# %%
from tabnanny import verbose


lstm_evaluation = lstm_model.evaluate(X_test, y_test, verbose=0)
gru_evaluation = gru_model.evaluate(X_test, y_test, verbose=0)

# %%
(lstm_evaluation, gru_evaluation)
# Out:
# ([0.004739011637866497, 0.048164211213588715, 17563.13671875],
#  0.004962691105902195)

# %%
if isinstance(gru_evaluation, float):
    print(f'GRU: Loss: {np.round(gru_evaluation,4)}, Mean Absolute Error: N/A, MAPE: N/A')
else:
    print(f'GRU: Loss: {np.round(gru_evaluation[0],4)}, Mean Absolute Error: {np.round(gru_evaluation[1],4)}, MAPE: {np.round(gru_evaluation[2],4)}')
# Out:
# GRU: Loss: 0.005, Mean Absolute Error: N/A, MAPE: N/A

# %%
lstm_Y = np.repeat(lstm_prediction, num_of_feature, axis=1)
lstm_y_inverse = sc_test.inverse_transform(lstm_Y)
gru_Y = np.repeat(gru_prediction, num_of_feature, axis=1)
gru_y_inverse = sc_test.inverse_transform(gru_Y)

# %%
Y_test = np.repeat(y_test, num_of_feature)
Y_test = Y_test.reshape(-1,num_of_feature)
Y_Test_transfer = sc_test.inverse_transform(Y_test)

# %%
lstm_Y_pred = lstm_y_inverse[:, 7]
gru_Y_pred = gru_y_inverse[:,7]
actual_Y_test = Y_Test_transfer[:, 7]

# %%
def plot_series(time, series_true, series_pred, format='-', start=0, end=None):
    plt.plot(time[start:end], series_true[start:end],format)
    plt.plot(time[start:end], series_pred[start:end],format)
    plt.xlabel('Time')
    plt.ylabel('Traffic Volume')
    plt.grid(True)
    plt.show()

# %%
lstm_y_pred = np.array(lstm_Y_pred)
gru_y_pred = np.array(gru_Y_pred)
y_true = np.array(actual_Y_test)

time_test = np.array(test_data['ds'])

plt.figure(figsize=(10,6))
plot_series(time_test[:50], y_true[:50],lstm_y_pred[:50])
plt.figure(figsize=(10,6))
plot_series(time_test[:50], y_true[:50],gru_y_pred[:50])

# %%
def plot_series_subplot(time, series_true, series_pred, ax,title="",format='-', start=0, end=None):
    xlabels = [str(time[i])[0:13] for i in range(len(time))]
    ax.plot(time[start:end], series_true[start:end],format)
    ax.plot(time[start:end], series_pred[start:end],format)
    ax.set_xlabel('Time')
    ax.set_title(title)
    #ax.set_xticks(time[start:end])
    ax.set_xticklabels(xlabels, rotation=50)
    ax.legend(['Actual','Predicted'], loc='best')
    ax.set_ylabel('Traffic Volume')
    ax.grid(True)

# %%
fig, ax = plt.subplots(2,2, figsize=(20,6))
plot_series_subplot(time_test[:50], y_true[:50],lstm_y_pred[:50],ax[0][0], "LSTM Prediction")
#plt.figure(figsize=(10,6))
plot_series_subplot(time_test[:50], y_true[:50],gru_y_pred[:50], ax[0][1],"GRU Prediction")
plot_series_subplot(time_test[200:300], y_true[200:300],lstm_y_pred[200:300],ax[1][0], "LSTM Prediction")
plot_series_subplot(time_test[200:300], y_true[200:300],gru_y_pred[200:300], ax[1][1],"GRU Prediction")
fig.tight_layout()
plt.savefig("/Users/nas/Documents/MRP/dataset/images/prediction_1.png", dpi=1200)
# Out:
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)

# %%
fig, ax = plt.subplots(2,2, figsize=(20,6))
plot_series_subplot(time_test[1000:1200], y_true[1000:1200],lstm_y_pred[1000:1200],ax[0][0], "LSTM Prediction")
plot_series_subplot(time_test[1000:1200], y_true[1000:1200],gru_y_pred[1000:1200], ax[0][1],"GRU Prediction")

plot_series_subplot(time_test[0:500], y_true[0:500],lstm_y_pred[0:500],ax[1][0], "LSTM Prediction")
plot_series_subplot(time_test[0:500], y_true[0:500],gru_y_pred[0:500], ax[1][1],"GRU Prediction")
fig.tight_layout()
plt.savefig("/Users/nas/Documents/MRP/dataset/images/prediction_1.png", dpi=1200)
# Out:
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)

# %%
fig, ax = plt.subplots(2,2, figsize=(20,6))
plot_series_subplot(time_test[50:80], y_true[50:80],lstm_y_pred[50:80],ax[0][0], "LSTM Prediction")
plot_series_subplot(time_test[50:80], y_true[50:80],gru_y_pred[50:80], ax[0][1],"GRU Prediction")

plot_series_subplot(time_test[100:120], y_true[100:120],lstm_y_pred[100:120],ax[1][0], "LSTM Prediction")
plot_series_subplot(time_test[100:120], y_true[100:120],gru_y_pred[100:120], ax[1][1],"GRU Prediction")
fig.tight_layout()
plt.savefig("/Users/nas/Documents/MRP/dataset/images/prediction_2.png", dpi=1200)
# Out:
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)

# %%
fig, ax = plt.subplots(2,2, figsize=(20,6))
plot_series_subplot(time_test[50:80], y_true[50:80],lstm_y_pred[50:80],ax[0][0], "LSTM Prediction")
plot_series_subplot(time_test[50:80], y_true[50:80],gru_y_pred[50:80], ax[0][1],"GRU Prediction")

plot_series_subplot(time_test[300:400], y_true[300:400],lstm_y_pred[300:400],ax[1][0], "LSTM Prediction")
plot_series_subplot(time_test[300:400], y_true[300:400],gru_y_pred[300:400], ax[1][1],"GRU Prediction")
fig.tight_layout()
plt.savefig("/Users/nas/Documents/MRP/dataset/images/prediction_2.png", dpi=1200)
# Out:
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
# /var/folders/_6/_998976521g0_jtnk0hrnh6r0000gn/T/ipykernel_78687/2374997822.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xlabels, rotation=50)
